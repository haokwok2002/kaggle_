# %%
# 系统库
import os
import subprocess
import time
import shutil
import json
import socket
from datetime import datetime, timedelta
import lightgbm as lgb
# 第三方科学计算 & 可视化
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 设置中文字体，避免乱码
plt.rcParams['font.sans-serif'] = ['SimHei']        # 黑体
plt.rcParams['axes.unicode_minus'] = False          # 解决负号显示成方块的问题

# 机器学习 & 优化
import xgboost as xgb
import optuna
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, make_scorer


# Kaggle API
from kaggle.api.kaggle_api_extended import KaggleApi








if socket.gethostname() == 'hao-2':
    dir = r'D:\数据\Kaggle\预测道路事故风险'
else:
    dir = os.getcwd()


DIRS = {
    "dir":              dir,                                       
    "DATA_DIR000":      os.path.join(dir, "DATA_DIR000"),
    "HISTORY":          os.path.join(dir, "HISTORY"),
    "SUBMISSION":       os.path.join(dir, "SUBMISSION"),
}

# 自动创建目录
for key, path in DIRS.items():
    os.makedirs(path, exist_ok=True)

# 打印时一行一个地址
print("✅ 路径已创建：\n")
for key, path in DIRS.items():
    print(f"{key:<12} : {path}")
# Out:
# ✅ 路径已创建：
#
# dir          : D:\数据\Kaggle\预测道路事故风险
# DATA_DIR000  : D:\数据\Kaggle\预测道路事故风险\DATA_DIR000
# HISTORY      : D:\数据\Kaggle\预测道路事故风险\HISTORY
# SUBMISSION   : D:\数据\Kaggle\预测道路事故风险\SUBMISSION

# %% [markdown]
# # 数据提取处理

# %%
# 加载Kaggle 训练集和 Bradley 熔点公开数据集

# Kaggle 提供的训练集和测试集
train_df = pd.read_csv(os.path.join(DIRS['DATA_DIR000'], "train.csv"))
test_df  = pd.read_csv(os.path.join(DIRS['DATA_DIR000'], "test.csv"))



# 输出数据集规模，确认加载成功
print("Train                        shape:", train_df.shape)
print("Test                         shape:", test_df.shape)
# Out:
# Train                        shape: (517754, 14)
# Test                         shape: (172585, 13)

# %%
# 检测 DataFrame 每列的数据类型、缺失值情况、唯一值数量，并给出部分示例值。
def dataframe_info(df: pd.DataFrame, n_sample: int = 6) -> pd.DataFrame:
    """
    检测 DataFrame 每列的数据类型、缺失值情况、唯一值数量，并给出部分示例值。
    
    参数:
        df       : 输入的 pandas DataFrame
        n_sample : 每列展示的样本值数量 (默认 3)
    
    返回:
        summary_df : 包含每列信息的 DataFrame
    """
    summary = pd.DataFrame({
        "数据类型": df.dtypes,
        "缺失值数量": df.isnull().sum(),
        "缺失值比例": df.isnull().mean(),
        "唯一值数量": df.nunique()
    })
    
    # 添加示例值（前 n_sample 个唯一值）
    summary["示例值 (samples)"] = df.apply(
        lambda col: col.dropna().unique()[:n_sample] if col.notnull().any() else []
    )
    
    # 按缺失比例排序
    summary = summary.sort_values("缺失值比例", ascending=False)
    print(df.columns.values)
    display(summary)
    # print(summary)


# 使用方法
dataframe_info(train_df, n_sample = 6)
dataframe_info(test_df, n_sample = 6)
# Out:
# ['id' 'road_type' 'num_lanes' 'curvature' 'speed_limit' 'lighting'
#  'weather' 'road_signs_present' 'public_road' 'time_of_day' 'holiday'
#  'school_season' 'num_reported_accidents' 'accident_risk']
#                            数据类型  缺失值数量  缺失值比例   唯一值数量  \
# id                        int64      0    0.0  517754
# road_type                object      0    0.0       3
# num_lanes                 int64      0    0.0       4
# curvature               float64      0    0.0     261
# speed_limit               int64      0    0.0       5
# lighting                 object      0    0.0       3
# weather                  object      0    0.0       3
# road_signs_present         bool      0    0.0       2
# public_road                bool      0    0.0       2
# time_of_day              object      0    0.0       3
# holiday                    bool      0    0.0       2
# school_season              bool      0    0.0       2
# num_reported_accidents    int64      0    0.0       8
# accident_risk           float64      0    0.0      98
#
#                                                示例值 (samples)
# id                                        [0, 1, 2, 3, 4, 5]
# road_type                            [urban, rural, highway]
# num_lanes                                       [2, 4, 1, 3]
# curvature               [0.06, 0.99, 0.63, 0.07, 0.58, 0.54]
# speed_limit                             [35, 70, 60, 45, 25]
# lighting                              [daylight, dim, night]
# weather                                [rainy, clear, foggy]
# road_signs_present                             [False, True]
# public_road                                    [True, False]
# time_of_day                    [afternoon, evening, morning]
# holiday                                        [False, True]
# school_season                                  [True, False]
# num_reported_accidents                    [1, 0, 2, 3, 4, 5]
# accident_risk            [0.13, 0.35, 0.3, 0.21, 0.56, 0.61]
# ['id' 'road_type' 'num_lanes' 'curvature' 'speed_limit' 'lighting'
#  'weather' 'road_signs_present' 'public_road' 'time_of_day' 'holiday'
#  'school_season' 'num_reported_accidents']
#                            数据类型  缺失值数量  缺失值比例   唯一值数量  \
# id                        int64      0    0.0  172585
# road_type                object      0    0.0       3
# num_lanes                 int64      0    0.0       4
# curvature               float64      0    0.0     195
# speed_limit               int64      0    0.0       5
# lighting                 object      0    0.0       3
# weather                  object      0    0.0       3
# road_signs_present         bool      0    0.0       2
# public_road                bool      0    0.0       2
# time_of_day              object      0    0.0       3
# holiday                    bool      0    0.0       2
# school_season              bool      0    0.0       2
# num_reported_accidents    int64      0    0.0       8
#
#                                                            示例值 (samples)
# id                      [517754, 517755, 517756, 517757, 517758, 517759]
# road_type                                        [highway, urban, rural]
# num_lanes                                                   [2, 3, 4, 1]
# curvature                           [0.34, 0.04, 0.59, 0.95, 0.86, 0.52]
# speed_limit                                         [45, 35, 25, 70, 60]
# lighting                                          [night, dim, daylight]
# weather                                            [clear, foggy, rainy]
# road_signs_present                                         [True, False]
# public_road                                                [True, False]
# time_of_day                                [afternoon, evening, morning]
# holiday                                                    [True, False]
# school_season                                              [True, False]
# num_reported_accidents                                [1, 0, 2, 3, 4, 6]

# %% [markdown]
# # 数据分析

# %%
# 打印清单
def config_to_str(config: dict, indent: int = 0) -> str:
    """递归生成配置字符串"""
    prefix = "     " * indent
    lines = []
    for key, value in config.items():
        if isinstance(value, dict):
            lines.append(f"{prefix}🔹 {key}:")
            lines.append(config_to_str(value, indent + 1))  # 递归拼接子字典
        else:
            lines.append(f"{prefix}- {key:<20}: {value}")
    return "\n".join(lines)

# %%
# 实验配置单
config = {
    # 固定开关
    "ISTEST"            : False,

    "use_feature_gen"   : True,
    "use_pca"           : True,
    "pca_components"    : 10,

    # 特征选择 XGBoost 参数
    "xgb_selector_model_params": {
        "n_estimators"  : 500,
        "max_depth"     : 6,
        "learning_rate" : 0.05,
        "random_state"  : 2025,
        "device"        : "cpu",
        "objective"     : "reg:squarederror",
        "tree_method"   : "hist",
        "verbosity"     : 0
    },

    "selector_threshold"  : "0*mean",   

    # # 训练设置
    # "xgb_train_model_params": {
    #     'max_depth'   : 6,
    #     'eta'         : 0.1,
    #     'tree_method' : 'hist',
    #     'eval_metric' : 'rmse',
    # },
    # "num_boost_round": 15000,


    # 训练设置（LightGBM）
    "lgb_train_model_params": {
        "objective": "regression",        # 回归任务
        "metric": "rmse",                 # 使用 RMSE 作为评估指标
        "boosting_type": "gbdt",          # 梯度提升树（默认）
        "learning_rate": 0.05,            # 学习率（原来 XGB 的 eta）
        "num_leaves": 31,                 # 控制树的复杂度
        "max_depth": -1,                  # -1 表示不限制深度
        "min_data_in_leaf": 20,           # 每个叶子最少样本数
        "feature_fraction": 0.9,          # 每次建树时使用的特征比例
        "bagging_fraction": 0.8,          # 每次建树时使用的数据比例
        "bagging_freq": 5,                # 每 5 次迭代进行一次 bagging
        "lambda_l1": 0.1,                 # L1 正则化
        "lambda_l2": 0.1,                 # L2 正则化
        "verbosity": -1                   # 不输出详细日志
    },
    "num_boost_round": 15000,             # 与 XGB 相同，用于控制最大迭代次数




}

# %%
# 数据拆分 (特征矩阵 与 目标向量)
# ============================================

import numpy as np
import pandas as pd

def prepare_features_and_target(train_df: pd.DataFrame, test_df: pd.DataFrame, config: dict):
    """
    数据拆分函数：构造训练集和测试集的特征矩阵与目标向量
    """

    
    # 2. 构造特征矩阵和目标向量
    features_train = train_df.drop(columns=['id', 'accident_risk'])   # 训练集特征 (X)
    target_train   = train_df['accident_risk']                            # 训练集目标 (y, 熔点)
    features_test  = test_df.drop(columns=['id'])    # 测试集特征 (无 Tm)



    # 随机选取部分特征（示例：50 个）
    if config["ISTEST"]:

        sample_len = 100
        features_train = train_df.drop(columns=['id', 'accident_risk']).iloc[:sample_len]  # 训练特征 (前 1000 条)
        target_train = train_df.iloc[:sample_len]['accident_risk']               # 训练目标
        features_test = test_df.drop(columns=['id'])                # 测试特征 (同样的特征列)




    # 3. 打印维度信息
    print("📊 数据拆分完成")
    print(f"训练集特征 features_train  shape   : {features_train.shape}")
    print(f"训练集目标   target_train  shape   : {target_train.shape}")
    print(f"测试集特征  features_test  shape   : {features_test.shape}")
    print(f"           features_train  类型    : {type(features_train)}")

    return features_train, target_train, features_test

# %% [markdown]
# ### 特征生成

# %%
def add_new_features(df: pd.DataFrame) -> pd.DataFrame:
    """
    针对道路事故预测构造新的衍生特征
    输入:
        df : pd.DataFrame
    输出:
        df_new : pd.DataFrame，包含新增特征
    """
    df = df.copy()
    shape_before = df.shape  # 原始维度

    # 1. 交互项
    df['Speed_x_Curvature'] = df['speed_limit'] * df['curvature']
    df['Lanes_x_Speed']     = df['num_lanes'] * df['speed_limit']
    df['Accidents_x_Speed'] = df['num_reported_accidents'] * df['speed_limit']

    # 类别交互项（需要后续 OneHotEncoder）
    df['RoadType_Time']     = df['road_type'] + "_" + df['time_of_day']
    df['Lighting_Weather']  = df['lighting'] + "_" + df['weather']

    # 2. 非线性变换
    df['Log_Accidents']     = np.log1p(df['num_reported_accidents'])  # log(1+x)

    # 分箱（自定义阈值，可调节）
    df['Accident_Bins'] = pd.cut(df['num_reported_accidents'],
                                bins=[-1, 0, 2, 5, np.inf],
                                labels=['none', 'low', 'medium', 'high'])

    # 3. 比率特征
    df['Accidents_per_Lane']   = df['num_reported_accidents'] / (df['num_lanes'] + 1)
    df['Curvature_per_Lane']   = df['curvature'] / (df['num_lanes'] + 1)
    df['Speed_per_Lane']       = df['speed_limit'] / (df['num_lanes'] + 1)


    shape_after = df.shape  # 新的维度

    print(f"{shape_before[0]} × {shape_before[1]} --> {shape_after[0]} × {shape_after[1]}   新增 {shape_after[1] - shape_before[1]} 列")



    return df

# %% [markdown]
# ### 手动编码 & 布尔转换

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

def fit_ohe(train_df: pd.DataFrame):
    """
    在训练集上自动检测 object/category 列，并拟合 OneHotEncoder。
    返回 encoder 对象和类别列名。
    """
    # 检测类别列
    cat_cols = train_df.select_dtypes(include=['object', 'category']).columns.tolist()
    print(f"检测到{len(cat_cols)}类: {cat_cols}")

    ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    ohe.fit(train_df[cat_cols])

    return ohe, cat_cols


def transform_ohe(df: pd.DataFrame, ohe: OneHotEncoder, cat_cols: list) -> pd.DataFrame:
    """
    使用已拟合的 OneHotEncoder 对 DataFrame 进行编码。
    自动处理 bool -> int，保持 train/test 一致。
    """
    df = df.copy()
    shape_before = df.shape

    # 布尔型转 int
    for col in df.select_dtypes('bool').columns:
        df[col] = df[col].astype(int)

    # OHE
    ohe_array = ohe.transform(df[cat_cols])
    ohe_cols = ohe.get_feature_names_out(cat_cols)
    ohe_df = pd.DataFrame(ohe_array, columns=ohe_cols, index=df.index)

    # 拼接
    df_enc = pd.concat([df.drop(columns=cat_cols), ohe_df], axis=1)

    shape_after = df_enc.shape
    print(f"{shape_before[0]} × {shape_before[1]} --> {shape_after[0]} × {shape_after[1]}   新增 {shape_after[1] - shape_before[1]} 列")

    return df_enc

# %% [markdown]
# ### 特征生成

# %% [markdown]
# ### PCA降维

# %%
# 对数据降维

import pandas as pd
import numpy as np
from sklearn.decomposition import TruncatedSVD
from scipy import sparse

def fit_svd(train_df: pd.DataFrame, n_components: int = 100, random_state: int = 42) -> TruncatedSVD:
    """
    在训练集上拟合 TruncatedSVD，并返回拟合好的模型。
    """
    X_sparse = sparse.csr_matrix(train_df.values)
    svd = TruncatedSVD(n_components=n_components, random_state=random_state)
    svd.fit(X_sparse)
    explained_var = svd.explained_variance_ratio_.sum()
    print(f"✅ SVD 已拟合完成 (n_components={n_components})，训练集累计解释方差比: {explained_var:.2%}")
    return svd

def transform_svd(df: pd.DataFrame, svd: TruncatedSVD) -> pd.DataFrame:
    """
    使用拟合好的 SVD 对数据集进行降维。
    """
    shape_before = df.shape
    X_sparse = sparse.csr_matrix(df.values)
    X_reduced_array = svd.transform(X_sparse)

    reduced_df = pd.DataFrame(
        X_reduced_array,
        index=df.index,
        columns=[f"SVD_{i+1}" for i in range(X_reduced_array.shape[1])]
    )

    shape_after = reduced_df.shape
    print(f"{shape_before[0]} × {shape_before[1]} --> {shape_after[0]} × {shape_after[1]}")
    return reduced_df

# %% [markdown]
# # 交叉训练验证

# %%
# Stratified K-Fold + XGBoost 进行训练验证，并保存实验结果
# ==============================================================
def run_kfold_xgb(features_train, target_train, features_test, config, DIRS, K_FOLDS=10, verbose=0):
    """
    使用 Stratified K-Fold + XGBoost 进行训练验证，并保存实验结果

    参数:
        features_train, target_train        : 训练集特征和标签
        features_test      : 测试集特征
        params      : XGBoost 最优参数 (dict)
        DIRS        : 保存结果的目录字典
        K_FOLDS     : 折数 (默认=5)
        verbose     : 是否打印详细信息
    """

    
        
    config["X shape"] = features_train.shape
    config["y shape"] = target_train.shape
    config["X_test shape"] = features_test.shape


    # ---------- 创建目录 ----------
    for _, path in DIRS.items():
        os.makedirs(path, exist_ok=True)


    time_str = datetime.now().strftime("%Y-%m-%d %H-%M-%S")
    history_DIR = os.path.join(DIRS['HISTORY'], time_str)
    os.makedirs(history_DIR, exist_ok=True)



    print("——" * 20)
    print(f"✅ 当前结果将保存到: {time_str}")


    # ---------- 定义交叉验证 ----------
    skfold = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
    yeo = PowerTransformer(method="yeo-johnson")                                # 定义 Yeo-Johnson 变换

    # ---------- 初始化存储 ----------
    oof_val = np.zeros(len(features_train))       # OOF 预测
    train_score, val_score = [], []  # 每折 LOSS
    test_pred = []                   # 每折 test 预测
    fold_records = []                # 保存每折信息
    all_importances = []             # 特征重要性
    elapsed_list = []                # 耗时记录



    # 循环每一折
    # ==============================================================

    for i, (train_idx, val_idx) in enumerate(skfold.split(features_train, pd.qcut(target_train, q=10).cat.codes), 1):

        # ----- 打印时间信息 -----
        start_now = datetime.now()
        start_str = start_now.strftime("%H:%M:%S")

        if elapsed_list:
            avg_time = np.mean(elapsed_list)
            est_end = start_now + timedelta(seconds=avg_time)

            # 每 5 个一组输出耗时
            parts = [f"{t:6.1f}s" for t in elapsed_list]
            grouped = [" ".join(parts[j:j+5]) for j in range(0, len(parts), 5)]
            elapsed_str = " /// ".join(grouped)

            print(
                f"🔄{i:2d}/{K_FOLDS} ST {start_str}"
                f" ET {est_end.strftime('%H:%M:%S')}"
                f" avg {avg_time:.1f}s"
                f" [{elapsed_str}]",
                end="\r", flush=True
            )
        else:
            print(f"🔄{i:2d}/{K_FOLDS} ST {start_str} ET (暂无历史数据)", end="\r", flush=True)



        # ----- 开始训练 -----
        t0 = time.time()

        # 1. 数据集划分
        x_train, x_val = features_train.iloc[train_idx], features_train.iloc[val_idx]
        y_train, y_val = target_train[train_idx], target_train[val_idx]

        # 2. Yeo-Johnson 变换
        y_train = yeo.fit_transform(y_train.values.reshape(-1, 1)).squeeze()
        y_val   = yeo.transform(y_val.values.reshape(-1, 1)).squeeze()


        # 3. 特征选择（轻量级 XGBoost）
        # 使用
        selector_model = xgb.XGBRegressor(**config["xgb_selector_model_params"])
        # selector_model = xgb.XGBRegressor(
        #     n_estimators   = 500,
        #     max_depth      = 6,
        #     learning_rate  = 0.05,
        #     random_state   = 2025,
        #     device         = "cpu",
        #     objective      = "reg:absoluteerror",
        #     tree_method    = "hist",
        #     verbosity      = 0
        # )
        
        

        selector_model.fit(x_train, y_train)

        selector = SelectFromModel(selector_model, prefit=True, threshold=config["selector_threshold"])
        selected_features = x_train.columns[selector.get_support()].tolist()
        if verbose > 0:
            print(f"✅ 选择的特征数量: {len(selected_features)}")


        # 4. 保留重要特征
        x_train_new = x_train[selected_features]
        x_val_new   = x_val[selected_features]
        x_test_new  = features_test[selected_features]







        # 5. 构造 LightGBM 数据集
        dtrain = lgb.Dataset(x_train_new, label=y_train)
        dval   = lgb.Dataset(x_val_new,   label=y_val)
        # dtest  = lgb.Dataset(x_test_new,  label=y_test)

        early_stop_rounds = 800 if config["lgb_train_model_params"]["learning_rate"] < 0.03 else 300
        use_early_stopping = (config["lgb_train_model_params"]["boosting_type"] != "dart")

        callbacks = []
        if use_early_stopping:
            callbacks.append(lgb.early_stopping(stopping_rounds=300))
        callbacks.append(lgb.log_evaluation(period=1000))

        # 6. LightGBM 训练
        lgb_model = lgb.train(
            params=config["lgb_train_model_params"],
            train_set=dtrain,
            valid_sets=[dtrain, dval],
            valid_names=["train", "valid"],
            num_boost_round=config["num_boost_round"],
        callbacks=callbacks
        )

        # # 保存模型
        # model_path = os.path.join(history_DIR, f"lgb_model_fold{i}.txt")
        # lgb_model.save_model(model_path)



        # 7. 获取特征重要性
        # imp_dict = xgb_model.get_score(importance_type="gain")
        # imp_df = pd.DataFrame(imp_dict.items(), columns=["Feature", "Importance"])
        # imp_df["Fold"] = i
        # all_importances.append(imp_df)


        # 8. 预测
        y_train_pred = lgb_model.predict(x_train_new, num_iteration=lgb_model.best_iteration)
        y_val_pred   = lgb_model.predict(x_val_new,   num_iteration=lgb_model.best_iteration)
        y_test_pred  = lgb_model.predict(x_test_new,  num_iteration=lgb_model.best_iteration)










        # 9. 逆变换
        y_train      = yeo.inverse_transform(y_train.reshape(-1, 1)).squeeze()
        y_val        = yeo.inverse_transform(y_val.reshape(-1, 1)).squeeze()
        y_train_pred = yeo.inverse_transform(y_train_pred.reshape(-1, 1)).squeeze()
        y_val_pred   = yeo.inverse_transform(y_val_pred.reshape(-1, 1)).squeeze()
        y_test_pred  = yeo.inverse_transform(y_test_pred.reshape(-1, 1)).squeeze()

        # 10. 计算 LOSS
        train_loss = np.sqrt(np.mean((y_train - y_train_pred) ** 2))
        val_loss   = np.sqrt(np.mean((y_val   - y_val_pred) ** 2))


        if verbose > 0:
            print(f"Fold {i}: Train LOSS={train_loss:.4f}, Val LOSS={val_loss:.4f}，用时 {elapsed:.2f} 秒")


        # ----- 保存结果 -----
        train_score.append(train_loss)
        val_score.append(val_loss)
        oof_val[val_idx] = y_val_pred
        test_pred.append(y_test_pred)

        elapsed = time.time() - t0
        elapsed_list.append(elapsed)

        fold_records.append({
            "Fold": i,
            "Train_LOSS": train_loss,
            "Val_LOSS": val_loss,
            "Num_Features": len(selected_features),
            "Selected_Features": selected_features,
            "elapsed": elapsed
        })

    # 保存整体结果
    # ==============================================================
    if verbose > 0:
        print("\n")
        print(f"📊 Train LOSS 平均值 : {np.mean(train_score):.4f}")
        print(f"📊 Val   LOSS 平均值 : {np.mean(val_score):.4f}")
        print(f"📊 Train LOSS 标准差 : {np.std(train_score, ddof=0):.4f}")
        print(f"📊 Val   LOSS 标准差 : {np.std(val_score, ddof=0):.4f}")

    # 参数
    with open(os.path.join(history_DIR, "config.json"), "w", encoding="utf-8") as f:
        json.dump(config, f, indent=4, ensure_ascii=False)

    # 每折信息
    folds_df = pd.DataFrame(fold_records)
    folds_df.to_csv(os.path.join(history_DIR, "folds_info.csv"), index=False, encoding="utf-8-sig")


    # # 特征重要性
    # if all_importances:
    #     valid_imps = [df for df in all_importances if not df.empty]
    #     all_imp_df = pd.concat(valid_imps, axis=0) if valid_imps else pd.DataFrame(columns=["Feature", "Importance", "Fold"])
    # else:
    #     all_imp_df = pd.DataFrame(columns=["Feature", "Importance", "Fold"])
    # all_imp_df.to_csv(os.path.join(history_DIR, "feature_importance_all.csv"), index=False, encoding="utf-8-sig")


    # 测试集预测
    test_pred_array = np.vstack(test_pred).T
    test_pred_df = pd.DataFrame(test_pred_array, columns=[f"Fold_{j+1}" for j in range(test_pred_array.shape[1])])
    test_pred_df["Final_Pred"] = test_pred_df.mean(axis=1)
    test_pred_df.to_csv(os.path.join(history_DIR, "test_predictions.csv"), index=False, encoding="utf-8-sig")

    # 总结
    with open(os.path.join(history_DIR, "summary.txt"), "w", encoding="utf-8") as f:
        f.write(f"Train LOSS Mean : {np.mean(train_score):.4f}\n")
        f.write(f"Val   LOSS Mean : {np.mean(val_score):.4f}\n")
        f.write(f"Train LOSS Std  : {np.std(train_score, ddof=0):.4f}\n")
        f.write(f"Val   LOSS Std  : {np.std(val_score, ddof=0):.4f}\n")


    # 最终提交
    final_score = np.mean(val_score)
    submission = pd.read_csv(os.path.join(DIRS['DATA_DIR000'], "sample_submission.csv"))
    submission["accident_risk"] = test_pred_df["Final_Pred"]

    submission_path = os.path.join(history_DIR, f"sub_{time_str}_{final_score:.8f}.csv")
    submission.to_csv(submission_path, index=False)
    submission.to_csv(os.path.join(DIRS['SUBMISSION'], f"sub_{time_str}_{final_score:.8f}.csv"), index=False)

        
    config["time_str"] = time_str
    config["score"] = final_score


    # ---------- 返回结果 ----------
    return {
        "oof_val": oof_val,
        "train_score": train_score,
        "val_score": val_score,
        "test_pred": test_pred_df,
        "folds_info": folds_df,
        # "feature_importance": all_imp_df,
        "submission_path": submission_path,
        "time": time_str,
        "final_score": final_score,
        "config": config
    }

# %% [markdown]
# # 单次训练推导

# %%
# 执行一次

# 准备流程---------------------------------------------------------------------------------------------------
# 打印当前config
print(config_to_str(config))

# Kaggle 提供的训练集和测试集
train_df = pd.read_csv(os.path.join(DIRS['DATA_DIR000'], "train.csv"))
test_df  = pd.read_csv(os.path.join(DIRS['DATA_DIR000'], "test.csv"))

# 数据拆分
print("数据拆分---------------------------")
features_train, target_train, features_test = prepare_features_and_target(train_df, test_df, config)


dataframe_info(features_train, n_sample = 6)


# 特征生成
print("特征生成---------------------------")
if config["use_feature_gen"]:
    features_train = add_new_features(features_train)
    features_test  = add_new_features(features_test)


dataframe_info(features_train, n_sample = 6)


# 手动编码 & 布尔转换
print("手动编码 & 布尔转换----------------")
# 在训练集上拟合
ohe, cat_cols = fit_ohe(features_train)
# 分别编码 train/test，保证一致
features_train = transform_ohe(features_train, ohe, cat_cols)
features_test  = transform_ohe(features_test,  ohe, cat_cols)


# 数据降维
print("数据降维---------------------------")
if config["use_pca"]:
    # 1. 在训练集上拟合
    svd = fit_svd(features_train, n_components = config["pca_components"], random_state=42)

    # 2. 分别对 train/test transform
    features_train_reduced = transform_svd(features_train, svd)
    features_test_reduced  = transform_svd(features_test, svd)

    shape_before_train = features_train.shape
    shape_before_test = features_test.shape

    features_train = pd.concat([features_train, features_train_reduced], axis=1)
    features_test = pd.concat([features_test, features_test_reduced], axis=1)

    shape_after_train = features_train.shape
    shape_after_test = features_test.shape

    print(f"Train: {shape_before_train[0]} × {shape_before_train[1]}  -->  {shape_after_train[0]} × {shape_after_train[1]}   新增 {shape_after_train[1] - shape_before_train[1]} 列")
    print(f"Test : {shape_before_test[0]} × {shape_before_test[1]}  -->  {shape_after_test[0]} × {shape_after_test[1]}   新增 {shape_after_test[1] - shape_before_test[1]} 列")



X, y, X_test = features_train, target_train, features_test
print("开始训练---------------------------")

# 准备流程---------------------------------------------------------------------------------------------------

results = run_kfold_xgb(X, y, X_test, config, DIRS, K_FOLDS = 10, verbose = 0)
config = results['config']
score = results['final_score']



print('\n',score)
# Out:
# - ISTEST              : False
# - use_feature_gen     : True
# - use_pca             : True
# - pca_components      : 10
# 🔹 xgb_selector_model_params:
#      - n_estimators        : 500
#      - max_depth           : 6
#      - learning_rate       : 0.05
#      - random_state        : 2025
#      - device              : cpu
#      - objective           : reg:squarederror
#      - tree_method         : hist
#      - verbosity           : 0
# - selector_threshold  : 0*mean
# 🔹 lgb_train_model_params:
#      - objective           : regression
#      - metric              : rmse
#      - boosting_type       : gbdt
#      - learning_rate       : 0.05
#      - num_leaves          : 31
#      - max_depth           : -1
#      - min_data_in_leaf    : 20
#      - feature_fraction    : 0.9
#      - bagging_fraction    : 0.8
#      - bagging_freq        : 5
#      - lambda_l1           : 0.1
#      - lambda_l2           : 0.1
#      - verbosity           : -1
# - num_boost_round     : 15000
# - X shape             : (517754, 59)
# - y shape             : (517754,)
# - X_test shape        : (172585, 59)
# 数据拆分---------------------------
# 📊 数据拆分完成
# 训练集特征 features_train  shape   : (517754, 12)
# 训练集目标   target_train  shape   : (517754,)
# 测试集特征  features_test  shape   : (172585, 12)
#            features_train  类型    : <class 'pandas.core.frame.DataFrame'>
# ['road_type' 'num_lanes' 'curvature' 'speed_limit' 'lighting' 'weather'
#  'road_signs_present' 'public_road' 'time_of_day' 'holiday'
#  'school_season' 'num_reported_accidents']
#                            数据类型  缺失值数量  缺失值比例  唯一值数量  \
# road_type                object      0    0.0      3
# num_lanes                 int64      0    0.0      4
# curvature               float64      0    0.0    261
# speed_limit               int64      0    0.0      5
# lighting                 object      0    0.0      3
# weather                  object      0    0.0      3
# road_signs_present         bool      0    0.0      2
# public_road                bool      0    0.0      2
# time_of_day              object      0    0.0      3
# holiday                    bool      0    0.0      2
# school_season              bool      0    0.0      2
# num_reported_accidents    int64      0    0.0      8
#
#                                                示例值 (samples)
# road_type                            [urban, rural, highway]
# num_lanes                                       [2, 4, 1, 3]
# curvature               [0.06, 0.99, 0.63, 0.07, 0.58, 0.54]
# speed_limit                             [35, 70, 60, 45, 25]
# lighting                              [daylight, dim, night]
# weather                                [rainy, clear, foggy]
# road_signs_present                             [False, True]
# public_road                                    [True, False]
# time_of_day                    [afternoon, evening, morning]
# holiday                                        [False, True]
# school_season                                  [True, False]
# num_reported_accidents                    [1, 0, 2, 3, 4, 5]
# 特征生成---------------------------
# 517754 × 12 --> 517754 × 22   新增 10 列
# 172585 × 12 --> 172585 × 22   新增 10 列
# ['road_type' 'num_lanes' 'curvature' 'speed_limit' 'lighting' 'weather'
#  'road_signs_present' 'public_road' 'time_of_day' 'holiday'
#  'school_season' 'num_reported_accidents' 'Speed_x_Curvature'
#  'Lanes_x_Speed' 'Accidents_x_Speed' 'RoadType_Time' 'Lighting_Weather'
#  'Log_Accidents' 'Accident_Bins' 'Accidents_per_Lane' 'Curvature_per_Lane'
#  'Speed_per_Lane']
#                             数据类型  缺失值数量  缺失值比例  唯一值数量  \
# road_type                 object      0    0.0      3
# num_lanes                  int64      0    0.0      4
# Curvature_per_Lane       float64      0    0.0    546
# Accidents_per_Lane       float64      0    0.0     21
# Accident_Bins           category      0    0.0      4
# Log_Accidents            float64      0    0.0      8
# Lighting_Weather          object      0    0.0      9
# RoadType_Time             object      0    0.0      9
# Accidents_x_Speed          int64      0    0.0     29
# Lanes_x_Speed              int64      0    0.0     17
# Speed_x_Curvature        float64      0    0.0    625
# num_reported_accidents     int64      0    0.0      8
# school_season               bool      0    0.0      2
# holiday                     bool      0    0.0      2
# time_of_day               object      0    0.0      3
# public_road                 bool      0    0.0      2
# road_signs_present          bool      0    0.0      2
# weather                   object      0    0.0      3
# lighting                  object      0    0.0      3
# speed_limit                int64      0    0.0      5
# curvature                float64      0    0.0    261
# Speed_per_Lane           float64      0    0.0     18
#
#                                                             示例值 (samples)
# road_type                                         [urban, rural, highway]
# num_lanes                                                    [2, 4, 1, 3]
# Curvature_per_Lane      [0.02, 0.198, 0.126, 0.014000000000000002, 0.2...
# Accidents_per_Lane          [0.3333333333333333, 0.0, 0.4, 0.2, 0.5, 1.0]
# Accident_Bins           ['low', 'none', 'medium', 'high']
# Categories (...
# Log_Accidents           [0.6931471805599453, 0.0, 1.0986122886681098, ...
# Lighting_Weather        [daylight_rainy, daylight_clear, dim_clear, di...
# RoadType_Time           [urban_afternoon, urban_evening, rural_morning...
# Accidents_x_Speed                                [35, 0, 140, 60, 90, 50]
# Lanes_x_Speed                                 [70, 140, 280, 60, 210, 45]
# Speed_x_Curvature       [2.1, 34.65, 44.1, 2.45, 34.8, 37.800000000000...
# num_reported_accidents                                 [1, 0, 2, 3, 4, 5]
# school_season                                               [True, False]
# holiday                                                     [False, True]
# time_of_day                                 [afternoon, evening, morning]
# public_road                                                 [True, False]
# road_signs_present                                          [False, True]
# weather                                             [rainy, clear, foggy]
# lighting                                           [daylight, dim, night]
# speed_limit                                          [35, 70, 60, 45, 25]
# curvature                            [0.06, 0.99, 0.63, 0.07, 0.58, 0.54]
# Speed_per_Lane          [11.666666666666666, 7.0, 14.0, 30.0, 17.5, 22.5]
# 手动编码 & 布尔转换----------------
# 检测到7类: ['road_type', 'lighting', 'weather', 'time_of_day', 'RoadType_Time', 'Lighting_Weather', 'Accident_Bins']
# 517754 × 22 --> 517754 × 49   新增 27 列
# 172585 × 22 --> 172585 × 49   新增 27 列
# 数据降维---------------------------
# ✅ SVD 已拟合完成 (n_components=10)，训练集累计解释方差比: 99.95%
# 517754 × 49 --> 517754 × 10
# 172585 × 49 --> 172585 × 10
# Train: 517754 × 49  -->  517754 × 59   新增 10 列
# Test : 172585 × 49  -->  172585 × 59   新增 10 列
# 开始训练---------------------------
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 02-08-53
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [785]	train's rmse: 0.33819	valid's rmse: 0.34435
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [611]	train's rmse: 0.339651	valid's rmse: 0.343783
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [480]	train's rmse: 0.340581	valid's rmse: 0.343426
# Training until validation scores don't improve for 300 rounds10.3s]
# Early stopping, best iteration is:
# [540]	train's rmse: 0.340151	valid's rmse: 0.343074
# Training until validation scores don't improve for 300 rounds10.3s   10.8s]
# Early stopping, best iteration is:
# [627]	train's rmse: 0.339341	valid's rmse: 0.34457
# Training until validation scores don't improve for 300 rounds10.3s   10.8s   11.5s]
# Early stopping, best iteration is:
# [610]	train's rmse: 0.339751	valid's rmse: 0.343612
# Training until validation scores don't improve for 300 rounds10.3s   10.8s   11.5s ///   11.2s]
# Early stopping, best iteration is:
# [746]	train's rmse: 0.338553	valid's rmse: 0.344752
# Training until validation scores don't improve for 300 rounds10.3s   10.8s   11.5s ///   11.2s   12.3s]
# Early stopping, best iteration is:
# [723]	train's rmse: 0.338687	valid's rmse: 0.345029
# Training until validation scores don't improve for 300 rounds10.3s   10.8s   11.5s ///   11.2s   12.3s   12.4s]
# Early stopping, best iteration is:
# [864]	train's rmse: 0.337895	valid's rmse: 0.34281
# Training until validation scores don't improve for 300 rounds10.3s   10.8s   11.5s ///   11.2s   12.3s   12.4s   12.8s]
# Early stopping, best iteration is:
# [823]	train's rmse: 0.338058	valid's rmse: 0.344834
#
#  0.05626612080837654

# %% [markdown]
# # 提交 kaggle 平台测试

# %%
# 根据 submission_time 定位文件路径 提交 kaggle 平台测试

import os
import itertools
import time
from kaggle.api.kaggle_api_extended import KaggleApi


def find_submission_file(submission_time, submission_dir):
    """
    在 submission_dir 下查找包含 submission_time 的文件
    一旦找到立刻返回完整路径；如果没找到则返回 None
    """
    for fname in os.listdir(submission_dir):
        if submission_time in fname:
            file_path = os.path.join(submission_dir, fname)
            print(f"✅ 找到目标文件: {fname}")
            return file_path
    
    print(f"⚠️ 未找到包含 {submission_time} 的文件")
    return None

def submit_and_get_score(file_path, competition_name, message="My submission"):
    """
    封装 Kaggle 提交并等待结果评分
    --------------------------------------
    file_path        : str  提交文件路径
    competition_name : str  Kaggle 比赛名称 (URL 最后一段)
    message          : str  提交备注
    """
    # 1. 配置 Kaggle API
    os.environ["KAGGLE_CONFIG_DIR"] = r"C:\Users\Admin\.kaggle"
    api = KaggleApi()
    api.authenticate()
    print("✅ Kaggle API 已经配置成功！")

    # 2. 提交文件
    api.competition_submit(
        file_name=file_path,
        competition=competition_name,
        message=message
    )
    print("✅ 提交完成！请等待评分...")

    # 3. 动态等待
    spinner = itertools.cycle(["|", "/", "-", "\\"])
    while True:
        submissions = api.competition_submissions(competition_name)
        latest = submissions[0]
        status_str = str(latest._status).lower()

        if "complete" in status_str and latest._public_score is not None:
            print("\n🎯 最终结果:")
            print(f"Public 分数 : {latest._public_score}")
            print(f"Private 分数: {latest._private_score}")
            print(f"提交 ID     : {latest._ref}")
            print(f"文件名      : {latest._file_name}")
            print(f"状态        : {latest._status}")
            print(f"提交时间    : {latest._date}")
            print(f"描述/备注   : {latest._description}")
            return latest

        if "pending" in status_str:
            spin_char = next(spinner)
            print(f"当前状态: {status_str} , 等待中 {spin_char}", end="\r", flush=True)
            time.sleep(0.2)  # 每 0.5 秒检查一次
            continue

        else:
            print(f"\n报错")
            print(f"submissions")
            
            break

# %% [markdown]
# ### 不轻易运行，再三考虑

# %%
# submission_time 提交
submission_time = "2025-10-24 01-23-41"
competition_name = "playground-series-s5e10"
message =  f"该提交文件的参数：\n{config_to_str(config)} "

target_file = find_submission_file(submission_time, DIRS['SUBMISSION'] )

# submit_and_get_score(target_file, competition_name, message)

# %% [markdown]
# # 参数优化

# %%
# 实验配置单
base_config = {
    # 固定开关
    "ISTEST"            : False,

    "use_feature_gen"   : False,
    "use_pca"           : True,
    "pca_components"    : 10,

    # 特征选择 XGBoost 参数
    "xgb_selector_model_params": {
        "n_estimators"  : 500,
        "max_depth"     : 6,
        "learning_rate" : 0.05,
        "random_state"  : 2025,
        "device"        : "cpu",
        "objective"     : "reg:squarederror",
        "tree_method"   : "hist",
        "verbosity"     : 0
    },

    "selector_threshold"  : "0*mean",   

    # # 训练设置
    # "xgb_train_model_params": {
    #     'max_depth'   : 6,
    #     'eta'         : 0.1,
    #     'tree_method' : 'hist',
    #     'eval_metric' : 'rmse',
    # },
    # "num_boost_round": 15000,


    # 训练设置（LightGBM）
    "lgb_train_model_params": {
        "objective": "regression",        # 回归任务
        "metric": "rmse",                 # 使用 RMSE 作为评估指标
        "boosting_type": "gbdt",          # 梯度提升树（默认）
        "learning_rate": 0.05,            # 学习率（原来 XGB 的 eta）
        "num_leaves": 31,                 # 控制树的复杂度
        "max_depth": -1,                  # -1 表示不限制深度
        "min_data_in_leaf": 20,           # 每个叶子最少样本数
        "feature_fraction": 0.9,          # 每次建树时使用的特征比例
        "bagging_fraction": 0.8,          # 每次建树时使用的数据比例
        "bagging_freq": 5,                # 每 5 次迭代进行一次 bagging
        "lambda_l1": 0.1,                 # L1 正则化
        "lambda_l2": 0.1,                 # L2 正则化
        "verbosity": -1                   # 不输出详细日志
    },
    "num_boost_round": 15000,             # 与 XGB 相同，用于控制最大迭代次数



}

# %%
# 定义优化任务  加入标识符 host: hao-2   ip: 192.168.40.1

import copy
import contextlib
import io

def objective(trial):
    """
    Optuna 的目标函数 (Objective Function)
    每次 trial 会生成一组超参数，用于训练 XGBoost 模型，
    并返回交叉验证的平均 RMSE 作为优化目标。
    """




    # 1. 定义 超参数 搜索空间
    # 拷贝一份 config，避免全局污染
    config = copy.deepcopy(base_config)

    # 只修改需要优化的参数
    config["use_feature_gen"]   = trial.suggest_categorical("use_feature_gen", [True, False])
    config["use_pca"]           = trial.suggest_categorical("use_pca", [True, False])
    config["pca_components"] = trial.suggest_categorical("pca_components", [5, 10, 15, 20])

    # config["xgb_selector_model_params"]["random_state"] = trial.suggest_categorical("selector_random_state", [2025])
    # config["xgb_selector_model_params"]["device"]       = trial.suggest_categorical("selector_device", ["cpu", "cuda"])

    # config["selector_threshold"] = trial.suggest_categorical("selector_threshold", ["0*mean", "0.25*mean", "0.5*mean", "0.75*mean", "mean"])

    # config["xgb_train_model_params"]["max_depth"] = trial.suggest_int("train_max_depth", 3, 12)
    # config["xgb_train_model_params"]["eta"] = trial.suggest_float("train_eta", 0.01 , 0.3 , log=True)
    config["lgb_train_model_params"]["learning_rate"] = trial.suggest_float(
        "learning_rate", 0.005, 0.1, log=True
    )
    config["lgb_train_model_params"]["num_leaves"] = trial.suggest_int(
        "num_leaves", 16, 256
    )
    # config["lgb_train_model_params"]["max_depth"] = trial.suggest_int(
    #     "max_depth", -1, 15
    # )
    config["lgb_train_model_params"]["min_data_in_leaf"] = trial.suggest_int(
        "min_data_in_leaf", 10, 100
    )
    config["lgb_train_model_params"]["feature_fraction"] = trial.suggest_float(
        "feature_fraction", 0.6, 1.0
    )
    config["lgb_train_model_params"]["bagging_fraction"] = trial.suggest_float(
        "bagging_fraction", 0.6, 1.0
    )
    config["lgb_train_model_params"]["bagging_freq"] = trial.suggest_int(
        "bagging_freq", 1, 10
    )
    config["lgb_train_model_params"]["lambda_l1"] = trial.suggest_float(
        "lambda_l1", 1e-3, 10.0, log=True
    )
    config["lgb_train_model_params"]["lambda_l2"] = trial.suggest_float(
        "lambda_l2", 1e-3, 10.0, log=True
    )
    config["lgb_train_model_params"]["boosting_type"] = trial.suggest_categorical(
        "boosting_type", ["gbdt", "dart"]
    )







    # 创建一个黑洞缓冲区
    f = io.StringIO()
    with contextlib.redirect_stdout(f):
        None




        # 准备流程---------------------------------------------------------------------------------------------------
        # 打印当前config
        print(config_to_str(config))

        # Kaggle 提供的训练集和测试集
        train_df = pd.read_csv(os.path.join(DIRS['DATA_DIR000'], "train.csv"))
        test_df  = pd.read_csv(os.path.join(DIRS['DATA_DIR000'], "test.csv"))

        # 数据拆分
        print("数据拆分---------------------------")
        features_train, target_train, features_test = prepare_features_and_target(train_df, test_df, config)

        # 特征生成
        print("特征生成---------------------------")
        if config["use_feature_gen"]:
            features_train = add_new_features(features_train)
            features_test  = add_new_features(features_test)


        # 手动编码 & 布尔转换
        print("手动编码 & 布尔转换----------------")
        # 在训练集上拟合
        ohe, cat_cols = fit_ohe(features_train)
        # 分别编码 train/test，保证一致
        features_train = transform_ohe(features_train, ohe, cat_cols)
        features_test  = transform_ohe(features_test,  ohe, cat_cols)


        # 数据降维
        print("数据降维---------------------------")
        if config["use_pca"]:
            # 1. 在训练集上拟合
            svd = fit_svd(features_train, n_components = config["pca_components"], random_state=42)

            # 2. 分别对 train/test transform
            features_train_reduced = transform_svd(features_train, svd)
            features_test_reduced  = transform_svd(features_test, svd)

            shape_before_train = features_train.shape
            shape_before_test = features_test.shape

            features_train = pd.concat([features_train, features_train_reduced], axis=1)
            features_test = pd.concat([features_test, features_test_reduced], axis=1)

            shape_after_train = features_train.shape
            shape_after_test = features_test.shape

            print(f"Train: {shape_before_train[0]} × {shape_before_train[1]}  -->  {shape_after_train[0]} × {shape_after_train[1]}   新增 {shape_after_train[1] - shape_before_train[1]} 列")
            print(f"Test : {shape_before_test[0]} × {shape_before_test[1]}  -->  {shape_after_test[0]} × {shape_after_test[1]}   新增 {shape_after_test[1] - shape_before_test[1]} 列")



        X, y, X_test = features_train, target_train, features_test
        print("开始训练---------------------------")

        # 准备流程---------------------------------------------------------------------------------------------------





    results = run_kfold_xgb(X, y, X_test, config, DIRS, K_FOLDS = 10, verbose = 0)
    config = results['config']
    score = results['final_score']



    HOSTNAME = socket.gethostname()
    HOST_IP = socket.gethostbyname(HOSTNAME)
    trial.set_user_attr("host", HOSTNAME)        # 你自己定义主机 A/B
    trial.set_user_attr("ip", HOST_IP)        # 你自己定义角色 A/B

    # 4. 返回平均 LOSS
    return score

# %%
STUDY_NAME = "test2LightGBM" if base_config["ISTEST"] else "Predicting Road Accident Risk LightGBM"

# %%
# 开始优化

# 1. 定义 SQLite 数据库存储路径

storage_url = "mysql+pymysql://user1:123456@10.162.147.95:3306/kaggle_melting_point_optuna"

study = optuna.create_study(
    study_name = STUDY_NAME,
    # study_name="ghsdjsrtjrswtjhwrt",
    storage=storage_url,
    load_if_exists=True
)

# 自动获取当前主机名\当前主机的 IP 地址
HOSTNAME = socket.gethostname()
HOST_IP = socket.gethostbyname(HOSTNAME)
print("主机名:", HOSTNAME," 主机 IP:", HOST_IP)
time.sleep(1)

# 5. 启动超参数搜索
print("🔎 开始超参数搜索...")
if base_config["ISTEST"]:
    study.optimize(objective, n_trials = 3)
else:
    study.optimize(objective, n_trials = 200)


# 6. 打印最优结果
print("\n✅ 训练完成！")
print(f"📊 已完成试验次数 : {len(study.trials)}")
print(f"🏆 最优试验编号   : {study.best_trial.number}")
print(f"📉 最优 LOSS       : {study.best_value}")
print(f"⚙️ 最优参数组合   : {study.best_trial.params}")
# Out:
# [I 2025-10-24 02:40:10,326] A new study created in RDB with name: Predicting Road Accident Risk LightGBM
# 主机名: hao-2  主机 IP: 192.168.40.1
# 🔎 开始超参数搜索...
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 02-40-16
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [118]	train's rmse: 0.337128	valid's rmse: 0.344459
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [134]	train's rmse: 0.336545	valid's rmse: 0.343626
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [118]	train's rmse: 0.337313	valid's rmse: 0.343178
# Training until validation scores don't improve for 300 rounds17.7s]
# Early stopping, best iteration is:
# [110]	train's rmse: 0.337764	valid's rmse: 0.343029
# Training until validation scores don't improve for 300 rounds17.7s   12.6s]
# Early stopping, best iteration is:
# [105]	train's rmse: 0.337821	valid's rmse: 0.344441
# Training until validation scores don't improve for 300 rounds17.7s   12.6s   13.8s]
# Early stopping, best iteration is:
# [117]	train's rmse: 0.337381	valid's rmse: 0.343479
# Training until validation scores don't improve for 300 rounds17.7s   12.6s   13.8s ///   18.1s]
# Early stopping, best iteration is:
# [123]	train's rmse: 0.336892	valid's rmse: 0.344668
# Training until validation scores don't improve for 300 rounds17.7s   12.6s   13.8s ///   18.1s   13.6s]
# Early stopping, best iteration is:
# [131]	train's rmse: 0.3363	valid's rmse: 0.344839
# Training until validation scores don't improve for 300 rounds17.7s   12.6s   13.8s ///   18.1s   13.6s   18.3s]
# Early stopping, best iteration is:
# [133]	train's rmse: 0.336465	valid's rmse: 0.342627
# Training until validation scores don't improve for 300 rounds17.7s   12.6s   13.8s ///   18.1s   13.6s   18.3s   12.8s]
# Early stopping, best iteration is:
# [126]	train's rmse: 0.336703	valid's rmse: 0.344887
# [I 2025-10-24 02:42:53,397] Trial 0 finished with value: 0.05623675145539836 and parameters: {'use_feature_gen': True, 'use_pca': True, 'pca_components': 20, 'learning_rate': 0.05855433126993213, 'num_leaves': 242, 'min_data_in_leaf': 77, 'feature_fraction': 0.8454640426355255, 'bagging_fraction': 0.7469011972885259, 'bagging_freq': 7, 'lambda_l1': 6.693584206135924, 'lambda_l2': 0.2765348113468092, 'boosting_type': 'gbdt'}. Best is trial 0 with value: 0.05623675145539836.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 02-42-55
# Training until validation scores don't improve for 300 rounds
# [1000]	train's rmse: 0.34455	valid's rmse: 0.345857
# [2000]	train's rmse: 0.343017	valid's rmse: 0.345098
# [3000]	train's rmse: 0.342014	valid's rmse: 0.344851
# [4000]	train's rmse: 0.341179	valid's rmse: 0.344766
# [5000]	train's rmse: 0.340385	valid's rmse: 0.344683
# [6000]	train's rmse: 0.339658	valid's rmse: 0.344658
# Early stopping, best iteration is:
# [5826]	train's rmse: 0.339781	valid's rmse: 0.344652
# Training until validation scores don't improve for 300 rounds
# [1000]	train's rmse: 0.344772	valid's rmse: 0.34461
# [2000]	train's rmse: 0.343215	valid's rmse: 0.344021
# [3000]	train's rmse: 0.342216	valid's rmse: 0.343871
# [4000]	train's rmse: 0.341369	valid's rmse: 0.343796
# Early stopping, best iteration is:
# [4337]	train's rmse: 0.341088	valid's rmse: 0.343785
# Training until validation scores don't improve for 300 rounds
# [1000]	train's rmse: 0.344783	valid's rmse: 0.344392
# [2000]	train's rmse: 0.343238	valid's rmse: 0.343642
# [3000]	train's rmse: 0.342208	valid's rmse: 0.34341
# [4000]	train's rmse: 0.341359	valid's rmse: 0.343341
# [5000]	train's rmse: 0.340565	valid's rmse: 0.343273
# [6000]	train's rmse: 0.339817	valid's rmse: 0.343252
# Early stopping, best iteration is:
# [6245]	train's rmse: 0.339638	valid's rmse: 0.343243
# Training until validation scores don't improve for 300 rounds41.6s]
# [1000]	train's rmse: 0.344697	valid's rmse: 0.344428
# [2000]	train's rmse: 0.343135	valid's rmse: 0.343584
# [3000]	train's rmse: 0.342121	valid's rmse: 0.343302
# [4000]	train's rmse: 0.341283	valid's rmse: 0.343185
# [5000]	train's rmse: 0.340508	valid's rmse: 0.343138
# Early stopping, best iteration is:
# [5692]	train's rmse: 0.339997	valid's rmse: 0.343113
# Training until validation scores don't improve for 300 rounds41.6s   39.5s]
# [1000]	train's rmse: 0.344691	valid's rmse: 0.345596
# [2000]	train's rmse: 0.343083	valid's rmse: 0.344902
# [3000]	train's rmse: 0.342097	valid's rmse: 0.344752
# [4000]	train's rmse: 0.34124	valid's rmse: 0.344684
# Early stopping, best iteration is:
# [4590]	train's rmse: 0.340774	valid's rmse: 0.344658
# Training until validation scores don't improve for 300 rounds41.6s   39.5s   33.1s]
# [1000]	train's rmse: 0.344799	valid's rmse: 0.34491
# [2000]	train's rmse: 0.343237	valid's rmse: 0.344192
# [3000]	train's rmse: 0.342266	valid's rmse: 0.344006
# [4000]	train's rmse: 0.341422	valid's rmse: 0.343913
# [5000]	train's rmse: 0.340632	valid's rmse: 0.343838
# [6000]	train's rmse: 0.339913	valid's rmse: 0.343816
# Early stopping, best iteration is:
# [6320]	train's rmse: 0.339687	valid's rmse: 0.343808
# Training until validation scores don't improve for 300 rounds41.6s   39.5s   33.1s ///   42.0s]
# [1000]	train's rmse: 0.344607	valid's rmse: 0.346151
# [2000]	train's rmse: 0.343046	valid's rmse: 0.345355
# [3000]	train's rmse: 0.342031	valid's rmse: 0.345099
# [4000]	train's rmse: 0.341189	valid's rmse: 0.345018
# [5000]	train's rmse: 0.34041	valid's rmse: 0.344971
# Early stopping, best iteration is:
# [4844]	train's rmse: 0.340524	valid's rmse: 0.344968
# Training until validation scores don't improve for 300 rounds41.6s   39.5s   33.1s ///   42.0s   34.3s]
# [1000]	train's rmse: 0.344503	valid's rmse: 0.34623
# [2000]	train's rmse: 0.342948	valid's rmse: 0.34551
# [3000]	train's rmse: 0.341956	valid's rmse: 0.345306
# [4000]	train's rmse: 0.341114	valid's rmse: 0.345233
# [5000]	train's rmse: 0.340332	valid's rmse: 0.345168
# [6000]	train's rmse: 0.339601	valid's rmse: 0.345152
# Early stopping, best iteration is:
# [6315]	train's rmse: 0.339378	valid's rmse: 0.345146
# Training until validation scores don't improve for 300 rounds41.6s   39.5s   33.1s ///   42.0s   34.3s   42.1s]
# [1000]	train's rmse: 0.344753	valid's rmse: 0.344205
# [2000]	train's rmse: 0.343175	valid's rmse: 0.3433
# [3000]	train's rmse: 0.342205	valid's rmse: 0.34307
# [4000]	train's rmse: 0.341351	valid's rmse: 0.342934
# [5000]	train's rmse: 0.340572	valid's rmse: 0.342868
# [6000]	train's rmse: 0.339853	valid's rmse: 0.34284
# [7000]	train's rmse: 0.339152	valid's rmse: 0.342819
# Early stopping, best iteration is:
# [7438]	train's rmse: 0.338857	valid's rmse: 0.342811
# Training until validation scores don't improve for 300 rounds41.6s   39.5s   33.1s ///   42.0s   34.3s   42.1s   47.9s]
# [1000]	train's rmse: 0.344583	valid's rmse: 0.346131
# [2000]	train's rmse: 0.343035	valid's rmse: 0.345294
# [3000]	train's rmse: 0.342066	valid's rmse: 0.345088
# [4000]	train's rmse: 0.341196	valid's rmse: 0.344927
# [5000]	train's rmse: 0.340415	valid's rmse: 0.344862
# [6000]	train's rmse: 0.339687	valid's rmse: 0.344814
# [7000]	train's rmse: 0.338999	valid's rmse: 0.34479
# Early stopping, best iteration is:
# [6925]	train's rmse: 0.33905	valid's rmse: 0.344787
# [I 2025-10-24 02:49:34,577] Trial 1 finished with value: 0.05628299929131834 and parameters: {'use_feature_gen': False, 'use_pca': True, 'pca_components': 10, 'learning_rate': 0.007963988791270001, 'num_leaves': 22, 'min_data_in_leaf': 67, 'feature_fraction': 0.7178025892239908, 'bagging_fraction': 0.7126133392111178, 'bagging_freq': 2, 'lambda_l1': 0.0021554917369354, 'lambda_l2': 0.0027367913297240017, 'boosting_type': 'gbdt'}. Best is trial 0 with value: 0.05623675145539836.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 02-49-35
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [592]	train's rmse: 0.338283	valid's rmse: 0.34387
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [570]	train's rmse: 0.338669	valid's rmse: 0.34288
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [626]	train's rmse: 0.338177	valid's rmse: 0.342605
# Training until validation scores don't improve for 300 rounds11.9s]
# Early stopping, best iteration is:
# [388]	train's rmse: 0.340093	valid's rmse: 0.34256
# Training until validation scores don't improve for 300 rounds11.9s   10.2s]
# Early stopping, best iteration is:
# [455]	train's rmse: 0.339397	valid's rmse: 0.344012
# Training until validation scores don't improve for 300 rounds11.9s   10.2s   10.6s]
# Early stopping, best iteration is:
# [372]	train's rmse: 0.340286	valid's rmse: 0.343027
# Training until validation scores don't improve for 300 rounds11.9s   10.2s   10.6s ///    9.8s]
# Early stopping, best iteration is:
# [596]	train's rmse: 0.33829	valid's rmse: 0.343957
# Training until validation scores don't improve for 300 rounds11.9s   10.2s   10.6s ///    9.8s   11.7s]
# Early stopping, best iteration is:
# [600]	train's rmse: 0.338193	valid's rmse: 0.344148
# Training until validation scores don't improve for 300 rounds11.9s   10.2s   10.6s ///    9.8s   11.7s   11.7s]
# Early stopping, best iteration is:
# [571]	train's rmse: 0.338652	valid's rmse: 0.342162
# Training until validation scores don't improve for 300 rounds11.9s   10.2s   10.6s ///    9.8s   11.7s   11.7s   11.4s]
# [1000]	train's rmse: 0.335416	valid's rmse: 0.344083
# Early stopping, best iteration is:
# [709]	train's rmse: 0.337432	valid's rmse: 0.343974
# [I 2025-10-24 02:51:30,472] Trial 2 finished with value: 0.05614115586133135 and parameters: {'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'learning_rate': 0.04396975969946361, 'num_leaves': 60, 'min_data_in_leaf': 39, 'feature_fraction': 0.838628315128256, 'bagging_fraction': 0.6832554536468092, 'bagging_freq': 2, 'lambda_l1': 0.817967898786827, 'lambda_l2': 0.0041471317233033505, 'boosting_type': 'gbdt'}. Best is trial 2 with value: 0.05614115586133135.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 02-51-31
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [695]	train's rmse: 0.337338	valid's rmse: 0.343557
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [690]	train's rmse: 0.337575	valid's rmse: 0.342647
# Training until validation scores don't improve for 300 rounds
# [1000]	train's rmse: 0.335335	valid's rmse: 0.342473
# Early stopping, best iteration is:
# [765]	train's rmse: 0.337056	valid's rmse: 0.342386
# Training until validation scores don't improve for 300 rounds18.2s]
# Early stopping, best iteration is:
# [597]	train's rmse: 0.3383	valid's rmse: 0.342116
# Training until validation scores don't improve for 300 rounds18.2s   16.1s]
# Early stopping, best iteration is:
# [559]	train's rmse: 0.338548	valid's rmse: 0.343776
# Training until validation scores don't improve for 300 rounds18.2s   16.1s   15.7s]
# Early stopping, best iteration is:
# [634]	train's rmse: 0.338137	valid's rmse: 0.342751
# Training until validation scores don't improve for 300 rounds18.2s   16.1s   15.7s ///   16.6s]
# Early stopping, best iteration is:
# [630]	train's rmse: 0.337994	valid's rmse: 0.343807
# Training until validation scores don't improve for 300 rounds18.2s   16.1s   15.7s ///   16.6s   16.6s]
# Early stopping, best iteration is:
# [682]	train's rmse: 0.33743	valid's rmse: 0.343986
# Training until validation scores don't improve for 300 rounds18.2s   16.1s   15.7s ///   16.6s   16.6s   17.2s]
# Early stopping, best iteration is:
# [677]	train's rmse: 0.337734	valid's rmse: 0.341808
# Training until validation scores don't improve for 300 rounds18.2s   16.1s   15.7s ///   16.6s   16.6s   17.2s   17.0s]
# [1000]	train's rmse: 0.335172	valid's rmse: 0.343829
# Early stopping, best iteration is:
# [755]	train's rmse: 0.336975	valid's rmse: 0.343782
# [I 2025-10-24 02:54:23,871] Trial 3 finished with value: 0.056091493835279595 and parameters: {'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'learning_rate': 0.014070743748395762, 'num_leaves': 175, 'min_data_in_leaf': 46, 'feature_fraction': 0.7816630185138349, 'bagging_fraction': 0.6550649106172352, 'bagging_freq': 5, 'lambda_l1': 0.0013655435173871426, 'lambda_l2': 0.7392541005877692, 'boosting_type': 'gbdt'}. Best is trial 3 with value: 0.056091493835279595.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 02-54-24
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [141]	train's rmse: 0.338522	valid's rmse: 0.3433
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [109]	train's rmse: 0.339743	valid's rmse: 0.342429
# Training until validation scores don't improve for 300 rounds
# Early stopping, best iteration is:
# [168]	train's rmse: 0.33807	valid's rmse: 0.342023
# Training until validation scores don't improve for 300 rounds7.7s]
# Early stopping, best iteration is:
# [123]	train's rmse: 0.339283	valid's rmse: 0.34194
# Training until validation scores don't improve for 300 rounds7.7s    7.4s]
# Early stopping, best iteration is:
# [144]	train's rmse: 0.338642	valid's rmse: 0.343359
# Training until validation scores don't improve for 300 rounds7.7s    7.4s    7.5s]
# Early stopping, best iteration is:
# [128]	train's rmse: 0.339254	valid's rmse: 0.342443
# Training until validation scores don't improve for 300 rounds7.7s    7.4s    7.5s ///    7.3s]
# Early stopping, best iteration is:
# [127]	train's rmse: 0.339042	valid's rmse: 0.343549
# Training until validation scores don't improve for 300 rounds7.7s    7.4s    7.5s ///    7.3s    7.5s]
# Early stopping, best iteration is:
# [146]	train's rmse: 0.338412	valid's rmse: 0.343948
# Training until validation scores don't improve for 300 rounds7.7s    7.4s    7.5s ///    7.3s    7.5s    7.4s]
# Early stopping, best iteration is:
# [115]	train's rmse: 0.339538	valid's rmse: 0.341436
# Training until validation scores don't improve for 300 rounds7.7s    7.4s    7.5s ///    7.3s    7.5s    7.4s    7.2s]
# Early stopping, best iteration is:
# [137]	train's rmse: 0.338708	valid's rmse: 0.343607
# [I 2025-10-24 02:55:41,564] Trial 4 finished with value: 0.05604852309513626 and parameters: {'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'learning_rate': 0.06625058653731754, 'num_leaves': 180, 'min_data_in_leaf': 83, 'feature_fraction': 0.9077185807172881, 'bagging_fraction': 0.9215159682485459, 'bagging_freq': 6, 'lambda_l1': 0.031125849539165376, 'lambda_l2': 0.5256515100596871, 'boosting_type': 'gbdt'}. Best is trial 4 with value: 0.05604852309513626.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 02-55-42
# [1000]	train's rmse: 0.3641	valid's rmse: 0.365109
# [2000]	train's rmse: 0.349092	valid's rmse: 0.350322
# [3000]	train's rmse: 0.344892	valid's rmse: 0.34635
# [4000]	train's rmse: 0.343237	valid's rmse: 0.344999
# [5000]	train's rmse: 0.342349	valid's rmse: 0.344305
# [6000]	train's rmse: 0.341871	valid's rmse: 0.344125
# [7000]	train's rmse: 0.341176	valid's rmse: 0.34374
# [8000]	train's rmse: 0.340691	valid's rmse: 0.343587
# [9000]	train's rmse: 0.340268	valid's rmse: 0.34349
# [10000]	train's rmse: 0.339864	valid's rmse: 0.343433
# [11000]	train's rmse: 0.339399	valid's rmse: 0.343391
# [12000]	train's rmse: 0.339025	valid's rmse: 0.343379
# [13000]	train's rmse: 0.338609	valid's rmse: 0.343345
# [14000]	train's rmse: 0.338223	valid's rmse: 0.343301
# [15000]	train's rmse: 0.337885	valid's rmse: 0.343399
# [1000]	train's rmse: 0.364287	valid's rmse: 0.363804]
# [2000]	train's rmse: 0.349274	valid's rmse: 0.348991
# [3000]	train's rmse: 0.345129	valid's rmse: 0.345083
# [4000]	train's rmse: 0.343493	valid's rmse: 0.343748
# [5000]	train's rmse: 0.342585	valid's rmse: 0.343054
# [6000]	train's rmse: 0.342115	valid's rmse: 0.342879
# [7000]	train's rmse: 0.341418	valid's rmse: 0.342511
# [8000]	train's rmse: 0.340943	valid's rmse: 0.342366
# [9000]	train's rmse: 0.340518	valid's rmse: 0.342223
# [10000]	train's rmse: 0.340112	valid's rmse: 0.342179
# [11000]	train's rmse: 0.339649	valid's rmse: 0.342177
# [12000]	train's rmse: 0.339292	valid's rmse: 0.342177
# [13000]	train's rmse: 0.338875	valid's rmse: 0.342156
# [14000]	train's rmse: 0.338492	valid's rmse: 0.342172
# [15000]	train's rmse: 0.338147	valid's rmse: 0.342249
# [1000]	train's rmse: 0.364157	valid's rmse: 0.363877 1121.9s]
# [2000]	train's rmse: 0.349336	valid's rmse: 0.349049
# [3000]	train's rmse: 0.345148	valid's rmse: 0.344937
# [4000]	train's rmse: 0.343443	valid's rmse: 0.343429
# [5000]	train's rmse: 0.342544	valid's rmse: 0.342751
# [6000]	train's rmse: 0.342062	valid's rmse: 0.342544
# [7000]	train's rmse: 0.34138	valid's rmse: 0.342187
# [8000]	train's rmse: 0.340888	valid's rmse: 0.342055
# [9000]	train's rmse: 0.340471	valid's rmse: 0.341938
# [10000]	train's rmse: 0.340066	valid's rmse: 0.341871
# [11000]	train's rmse: 0.3396	valid's rmse: 0.341851
# [12000]	train's rmse: 0.339222	valid's rmse: 0.341845
# [13000]	train's rmse: 0.338807	valid's rmse: 0.341806
# [14000]	train's rmse: 0.338414	valid's rmse: 0.341815
# [15000]	train's rmse: 0.33807	valid's rmse: 0.341873
# [1000]	train's rmse: 0.36411	valid's rmse: 0.363166s 1121.9s 1120.3s]
# [2000]	train's rmse: 0.349255	valid's rmse: 0.348616
# [3000]	train's rmse: 0.345095	valid's rmse: 0.344734
# [4000]	train's rmse: 0.34338	valid's rmse: 0.343355
# [5000]	train's rmse: 0.342495	valid's rmse: 0.342725
# [6000]	train's rmse: 0.342005	valid's rmse: 0.342541
# [7000]	train's rmse: 0.341316	valid's rmse: 0.342173
# [8000]	train's rmse: 0.340834	valid's rmse: 0.342051
# [9000]	train's rmse: 0.340405	valid's rmse: 0.341922
# [10000]	train's rmse: 0.339996	valid's rmse: 0.341879
# [11000]	train's rmse: 0.339517	valid's rmse: 0.341886
# [12000]	train's rmse: 0.339142	valid's rmse: 0.341873
# [13000]	train's rmse: 0.338727	valid's rmse: 0.34185
# [14000]	train's rmse: 0.338326	valid's rmse: 0.341831
# [15000]	train's rmse: 0.337982	valid's rmse: 0.341913
# [1000]	train's rmse: 0.364078	valid's rmse: 0.364871 1121.9s 1120.3s 1130.1s]
# [2000]	train's rmse: 0.349174	valid's rmse: 0.350209
# [3000]	train's rmse: 0.34501	valid's rmse: 0.34631
# [4000]	train's rmse: 0.343311	valid's rmse: 0.344947
# [5000]	train's rmse: 0.342437	valid's rmse: 0.344324
# [6000]	train's rmse: 0.341941	valid's rmse: 0.344144
# [7000]	train's rmse: 0.34125	valid's rmse: 0.34378
# [8000]	train's rmse: 0.340754	valid's rmse: 0.343633
# [9000]	train's rmse: 0.340334	valid's rmse: 0.343555
# [10000]	train's rmse: 0.339935	valid's rmse: 0.343499
# [11000]	train's rmse: 0.339459	valid's rmse: 0.34349
# [12000]	train's rmse: 0.339102	valid's rmse: 0.343481
# [13000]	train's rmse: 0.338689	valid's rmse: 0.343466
# [14000]	train's rmse: 0.338303	valid's rmse: 0.34345
# [15000]	train's rmse: 0.337952	valid's rmse: 0.343542
# [1000]	train's rmse: 0.364302	valid's rmse: 0.36417s 1121.9s 1120.3s 1130.1s 1136.8s]
# [2000]	train's rmse: 0.349343	valid's rmse: 0.349371
# [3000]	train's rmse: 0.345172	valid's rmse: 0.345439
# [4000]	train's rmse: 0.343502	valid's rmse: 0.344036
# [5000]	train's rmse: 0.342607	valid's rmse: 0.34335
# [6000]	train's rmse: 0.342125	valid's rmse: 0.343173
# [7000]	train's rmse: 0.341432	valid's rmse: 0.342803
# [8000]	train's rmse: 0.340939	valid's rmse: 0.342652
# [9000]	train's rmse: 0.340516	valid's rmse: 0.342549
# [10000]	train's rmse: 0.340103	valid's rmse: 0.342506
# [11000]	train's rmse: 0.339628	valid's rmse: 0.342505
# [12000]	train's rmse: 0.339265	valid's rmse: 0.342529
# [13000]	train's rmse: 0.338854	valid's rmse: 0.342517
# [14000]	train's rmse: 0.338455	valid's rmse: 0.342503
# [15000]	train's rmse: 0.338109	valid's rmse: 0.342618
# [1000]	train's rmse: 0.364165	valid's rmse: 0.365295 1121.9s 1120.3s 1130.1s 1136.8s /// 1125.9s]
# [2000]	train's rmse: 0.349128	valid's rmse: 0.350331
# [3000]	train's rmse: 0.344967	valid's rmse: 0.346352
# [4000]	train's rmse: 0.343324	valid's rmse: 0.34499
# [5000]	train's rmse: 0.342415	valid's rmse: 0.344313
# [6000]	train's rmse: 0.34193	valid's rmse: 0.344118
# [7000]	train's rmse: 0.341245	valid's rmse: 0.343788
# [8000]	train's rmse: 0.340757	valid's rmse: 0.34365
# [9000]	train's rmse: 0.340328	valid's rmse: 0.343548
# [10000]	train's rmse: 0.339922	valid's rmse: 0.343518
# [11000]	train's rmse: 0.339441	valid's rmse: 0.343501
# [12000]	train's rmse: 0.33907	valid's rmse: 0.34352
# [13000]	train's rmse: 0.338657	valid's rmse: 0.343509
# [14000]	train's rmse: 0.338256	valid's rmse: 0.343505
# [15000]	train's rmse: 0.337912	valid's rmse: 0.343555
# [1000]	train's rmse: 0.364012	valid's rmse: 0.365076 1121.9s 1120.3s 1130.1s 1136.8s /// 1125.9s 1132.2s]
# [2000]	train's rmse: 0.34906	valid's rmse: 0.350458
# [3000]	train's rmse: 0.344869	valid's rmse: 0.346438
# [4000]	train's rmse: 0.343249	valid's rmse: 0.345107
# [5000]	train's rmse: 0.342339	valid's rmse: 0.344434
# [6000]	train's rmse: 0.341845	valid's rmse: 0.344243
# [7000]	train's rmse: 0.341146	valid's rmse: 0.343869
# [8000]	train's rmse: 0.34068	valid's rmse: 0.343713
# [9000]	train's rmse: 0.340251	valid's rmse: 0.343577
# [10000]	train's rmse: 0.339843	valid's rmse: 0.343513
# [11000]	train's rmse: 0.339388	valid's rmse: 0.343475
# [12000]	train's rmse: 0.339015	valid's rmse: 0.343452
# [13000]	train's rmse: 0.338609	valid's rmse: 0.343407
# [14000]	train's rmse: 0.338212	valid's rmse: 0.34339
# [15000]	train's rmse: 0.337876	valid's rmse: 0.343447
# [1000]	train's rmse: 0.364255	valid's rmse: 0.36404s 1121.9s 1120.3s 1130.1s 1136.8s /// 1125.9s 1132.2s 1181.3s]
# [2000]	train's rmse: 0.349266	valid's rmse: 0.348783
# [3000]	train's rmse: 0.3451	valid's rmse: 0.344671
# [4000]	train's rmse: 0.34345	valid's rmse: 0.343211
# [5000]	train's rmse: 0.342536	valid's rmse: 0.342482
# [6000]	train's rmse: 0.342053	valid's rmse: 0.342261
# [7000]	train's rmse: 0.341352	valid's rmse: 0.341828
# [8000]	train's rmse: 0.340876	valid's rmse: 0.341687
# [9000]	train's rmse: 0.340453	valid's rmse: 0.341555
# [10000]	train's rmse: 0.340046	valid's rmse: 0.341507
# [11000]	train's rmse: 0.339575	valid's rmse: 0.341476
# [12000]	train's rmse: 0.339199	valid's rmse: 0.341467
# [13000]	train's rmse: 0.33879	valid's rmse: 0.341446
# [14000]	train's rmse: 0.338395	valid's rmse: 0.341403
# [15000]	train's rmse: 0.338049	valid's rmse: 0.341507
# [1000]	train's rmse: 0.364078	valid's rmse: 0.365395 1121.9s 1120.3s 1130.1s 1136.8s /// 1125.9s 1132.2s 1181.3s 1131.9s]
# [2000]	train's rmse: 0.349096	valid's rmse: 0.350634
# [3000]	train's rmse: 0.344917	valid's rmse: 0.346652
# [4000]	train's rmse: 0.343261	valid's rmse: 0.34523
# [5000]	train's rmse: 0.342353	valid's rmse: 0.344539
# [6000]	train's rmse: 0.341874	valid's rmse: 0.344324
# [7000]	train's rmse: 0.34117	valid's rmse: 0.343937
# [8000]	train's rmse: 0.340694	valid's rmse: 0.343773
# [9000]	train's rmse: 0.340276	valid's rmse: 0.343654
# [10000]	train's rmse: 0.339867	valid's rmse: 0.343575
# [11000]	train's rmse: 0.3394	valid's rmse: 0.343545
# [12000]	train's rmse: 0.339038	valid's rmse: 0.34354
# [13000]	train's rmse: 0.338628	valid's rmse: 0.3435
# [14000]	train's rmse: 0.338228	valid's rmse: 0.343467
# [15000]	train's rmse: 0.337889	valid's rmse: 0.343538
# [I 2025-10-24 06:04:36,061] Trial 5 finished with value: 0.05605546091310608 and parameters: {'use_feature_gen': True, 'use_pca': False, 'pca_components': 15, 'learning_rate': 0.013301417227872592, 'num_leaves': 36, 'min_data_in_leaf': 21, 'feature_fraction': 0.7930033350109744, 'bagging_fraction': 0.6307886626465097, 'bagging_freq': 3, 'lambda_l1': 1.482043761071851, 'lambda_l2': 1.3227988976005378, 'boosting_type': 'dart'}. Best is trial 4 with value: 0.05604852309513626.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 06-04-37
# [1000]	train's rmse: 0.33542	valid's rmse: 0.344923
# [2000]	train's rmse: 0.328255	valid's rmse: 0.345125
# [3000]	train's rmse: 0.321304	valid's rmse: 0.346121
# [4000]	train's rmse: 0.314476	valid's rmse: 0.347564
# [5000]	train's rmse: 0.309159	valid's rmse: 0.348638
# [6000]	train's rmse: 0.303782	valid's rmse: 0.349816
# [7000]	train's rmse: 0.298632	valid's rmse: 0.351034
# [8000]	train's rmse: 0.293945	valid's rmse: 0.352145
# [9000]	train's rmse: 0.289591	valid's rmse: 0.353231
# [10000]	train's rmse: 0.285221	valid's rmse: 0.35436
# [11000]	train's rmse: 0.280515	valid's rmse: 0.355609
# [12000]	train's rmse: 0.276699	valid's rmse: 0.356583
# [13000]	train's rmse: 0.273053	valid's rmse: 0.357645
# [14000]	train's rmse: 0.269569	valid's rmse: 0.358609
# [15000]	train's rmse: 0.266056	valid's rmse: 0.359629
# [1000]	train's rmse: 0.335685	valid's rmse: 0.343494]
# [2000]	train's rmse: 0.328612	valid's rmse: 0.343591
# [3000]	train's rmse: 0.321647	valid's rmse: 0.344758
# [4000]	train's rmse: 0.3147	valid's rmse: 0.346145
# [5000]	train's rmse: 0.309434	valid's rmse: 0.347049
# [6000]	train's rmse: 0.304039	valid's rmse: 0.348196
# [7000]	train's rmse: 0.298892	valid's rmse: 0.349427
# [8000]	train's rmse: 0.294293	valid's rmse: 0.350573
# [9000]	train's rmse: 0.290034	valid's rmse: 0.351583
# [10000]	train's rmse: 0.285675	valid's rmse: 0.352798
# [11000]	train's rmse: 0.280869	valid's rmse: 0.353968
# [12000]	train's rmse: 0.27708	valid's rmse: 0.35485
# [13000]	train's rmse: 0.273424	valid's rmse: 0.355825
# [14000]	train's rmse: 0.270006	valid's rmse: 0.356742
# [15000]	train's rmse: 0.266505	valid's rmse: 0.357768
# [1000]	train's rmse: 0.335586	valid's rmse: 0.34336s 1680.7s]
# [2000]	train's rmse: 0.328554	valid's rmse: 0.34363
# [3000]	train's rmse: 0.321564	valid's rmse: 0.344891
# [4000]	train's rmse: 0.314502	valid's rmse: 0.346454
# [5000]	train's rmse: 0.309289	valid's rmse: 0.347437
# [6000]	train's rmse: 0.303974	valid's rmse: 0.348599
# [7000]	train's rmse: 0.298899	valid's rmse: 0.349728
# [8000]	train's rmse: 0.294167	valid's rmse: 0.350938
# [9000]	train's rmse: 0.289794	valid's rmse: 0.352083
# [10000]	train's rmse: 0.285517	valid's rmse: 0.353247
# [11000]	train's rmse: 0.280843	valid's rmse: 0.354634
# [12000]	train's rmse: 0.277085	valid's rmse: 0.355588
# [13000]	train's rmse: 0.273438	valid's rmse: 0.356601
# [14000]	train's rmse: 0.269977	valid's rmse: 0.357594
# [15000]	train's rmse: 0.266485	valid's rmse: 0.358701
# [1000]	train's rmse: 0.335546	valid's rmse: 0.343159 1680.7s 1692.4s]
# [2000]	train's rmse: 0.328519	valid's rmse: 0.343576
# [3000]	train's rmse: 0.321468	valid's rmse: 0.344792
# [4000]	train's rmse: 0.314551	valid's rmse: 0.346279
# [5000]	train's rmse: 0.309159	valid's rmse: 0.347495
# [6000]	train's rmse: 0.303804	valid's rmse: 0.348637
# [7000]	train's rmse: 0.29872	valid's rmse: 0.349707
# [8000]	train's rmse: 0.294019	valid's rmse: 0.350937
# [9000]	train's rmse: 0.289627	valid's rmse: 0.352058
# [10000]	train's rmse: 0.285221	valid's rmse: 0.353164
# [11000]	train's rmse: 0.280487	valid's rmse: 0.354463
# [12000]	train's rmse: 0.276654	valid's rmse: 0.355548
# [13000]	train's rmse: 0.273	valid's rmse: 0.356604
# [14000]	train's rmse: 0.269543	valid's rmse: 0.357623
# [15000]	train's rmse: 0.266117	valid's rmse: 0.358692
# [1000]	train's rmse: 0.335491	valid's rmse: 0.344859 1680.7s 1692.4s 1689.3s]
# [2000]	train's rmse: 0.328446	valid's rmse: 0.345154
# [3000]	train's rmse: 0.321521	valid's rmse: 0.346061
# [4000]	train's rmse: 0.314504	valid's rmse: 0.347403
# [5000]	train's rmse: 0.309232	valid's rmse: 0.348508
# [6000]	train's rmse: 0.303885	valid's rmse: 0.349658
# [7000]	train's rmse: 0.298749	valid's rmse: 0.35101
# [8000]	train's rmse: 0.293982	valid's rmse: 0.352116
# [9000]	train's rmse: 0.289609	valid's rmse: 0.353143
# [10000]	train's rmse: 0.285263	valid's rmse: 0.354222
# [11000]	train's rmse: 0.280516	valid's rmse: 0.355534
# [12000]	train's rmse: 0.276639	valid's rmse: 0.356598
# [13000]	train's rmse: 0.27292	valid's rmse: 0.357674
# [14000]	train's rmse: 0.269617	valid's rmse: 0.358726
# [15000]	train's rmse: 0.266147	valid's rmse: 0.359754
# [1000]	train's rmse: 0.33563	valid's rmse: 0.343939s 1680.7s 1692.4s 1689.3s 1713.2s]
# [2000]	train's rmse: 0.328573	valid's rmse: 0.344119
# [3000]	train's rmse: 0.321648	valid's rmse: 0.345156
# [4000]	train's rmse: 0.314707	valid's rmse: 0.34671
# [5000]	train's rmse: 0.309265	valid's rmse: 0.347965
# [6000]	train's rmse: 0.303917	valid's rmse: 0.349305
# [7000]	train's rmse: 0.298692	valid's rmse: 0.350374
# [8000]	train's rmse: 0.29398	valid's rmse: 0.351618
# [9000]	train's rmse: 0.289642	valid's rmse: 0.352783
# [10000]	train's rmse: 0.285344	valid's rmse: 0.35407
# [11000]	train's rmse: 0.28068	valid's rmse: 0.355257
# [12000]	train's rmse: 0.276925	valid's rmse: 0.35616
# [13000]	train's rmse: 0.273232	valid's rmse: 0.357135
# [14000]	train's rmse: 0.269784	valid's rmse: 0.358027
# [15000]	train's rmse: 0.266246	valid's rmse: 0.359061
# [1000]	train's rmse: 0.335364	valid's rmse: 0.34491s 1680.7s 1692.4s 1689.3s 1713.2s /// 1708.0s]
# [2000]	train's rmse: 0.328358	valid's rmse: 0.345237
# [3000]	train's rmse: 0.321367	valid's rmse: 0.346332
# [4000]	train's rmse: 0.31445	valid's rmse: 0.347772
# [5000]	train's rmse: 0.309195	valid's rmse: 0.348628
# [6000]	train's rmse: 0.303814	valid's rmse: 0.349826
# [7000]	train's rmse: 0.298701	valid's rmse: 0.351047
# [8000]	train's rmse: 0.294037	valid's rmse: 0.352296
# [9000]	train's rmse: 0.289744	valid's rmse: 0.353489
# [10000]	train's rmse: 0.285523	valid's rmse: 0.354632
# [11000]	train's rmse: 0.280748	valid's rmse: 0.355864
# [12000]	train's rmse: 0.276982	valid's rmse: 0.356909
# [13000]	train's rmse: 0.273362	valid's rmse: 0.357891
# [14000]	train's rmse: 0.269832	valid's rmse: 0.358921
# [15000]	train's rmse: 0.2663	valid's rmse: 0.359928
# [1000]	train's rmse: 0.335432	valid's rmse: 0.344812 1680.7s 1692.4s 1689.3s 1713.2s /// 1708.0s 1728.1s]
# [2000]	train's rmse: 0.32838	valid's rmse: 0.344862
# [3000]	train's rmse: 0.321388	valid's rmse: 0.346011
# [4000]	train's rmse: 0.314493	valid's rmse: 0.347398
# [5000]	train's rmse: 0.309135	valid's rmse: 0.348326
# [6000]	train's rmse: 0.303782	valid's rmse: 0.34955
# [7000]	train's rmse: 0.298715	valid's rmse: 0.350593
# [8000]	train's rmse: 0.294018	valid's rmse: 0.351712
# [9000]	train's rmse: 0.289671	valid's rmse: 0.352883
# [10000]	train's rmse: 0.285364	valid's rmse: 0.354008
# [11000]	train's rmse: 0.280631	valid's rmse: 0.355207
# [12000]	train's rmse: 0.276864	valid's rmse: 0.356319
# [13000]	train's rmse: 0.273203	valid's rmse: 0.357379
# [14000]	train's rmse: 0.269775	valid's rmse: 0.358254
# [15000]	train's rmse: 0.266242	valid's rmse: 0.359283
# [1000]	train's rmse: 0.335559	valid's rmse: 0.342943 1680.7s 1692.4s 1689.3s 1713.2s /// 1708.0s 1728.1s 1721.9s]
# [2000]	train's rmse: 0.328457	valid's rmse: 0.343132
# [3000]	train's rmse: 0.321521	valid's rmse: 0.344042
# [4000]	train's rmse: 0.314547	valid's rmse: 0.345458
# [5000]	train's rmse: 0.30932	valid's rmse: 0.346531
# [6000]	train's rmse: 0.303945	valid's rmse: 0.347891
# [7000]	train's rmse: 0.298909	valid's rmse: 0.348981
# [8000]	train's rmse: 0.294214	valid's rmse: 0.350093
# [9000]	train's rmse: 0.289908	valid's rmse: 0.351218
# [10000]	train's rmse: 0.285551	valid's rmse: 0.352282
# [11000]	train's rmse: 0.280827	valid's rmse: 0.353486
# [12000]	train's rmse: 0.276992	valid's rmse: 0.354464
# [13000]	train's rmse: 0.273234	valid's rmse: 0.355551
# [14000]	train's rmse: 0.269642	valid's rmse: 0.356621
# [15000]	train's rmse: 0.2661	valid's rmse: 0.357643
# [1000]	train's rmse: 0.335435	valid's rmse: 0.344689 1680.7s 1692.4s 1689.3s 1713.2s /// 1708.0s 1728.1s 1721.9s 1740.3s]
# [2000]	train's rmse: 0.328381	valid's rmse: 0.344951
# [3000]	train's rmse: 0.321399	valid's rmse: 0.345897
# [4000]	train's rmse: 0.314466	valid's rmse: 0.347282
# [5000]	train's rmse: 0.309283	valid's rmse: 0.348412
# [6000]	train's rmse: 0.304006	valid's rmse: 0.349557
# [7000]	train's rmse: 0.298835	valid's rmse: 0.350845
# [8000]	train's rmse: 0.294186	valid's rmse: 0.352038
# [9000]	train's rmse: 0.289871	valid's rmse: 0.353239
# [10000]	train's rmse: 0.285589	valid's rmse: 0.354473
# [11000]	train's rmse: 0.280814	valid's rmse: 0.355874
# [12000]	train's rmse: 0.276983	valid's rmse: 0.356904
# [13000]	train's rmse: 0.273279	valid's rmse: 0.357969
# [14000]	train's rmse: 0.269787	valid's rmse: 0.358963
# [15000]	train's rmse: 0.266236	valid's rmse: 0.359906
# [I 2025-10-24 10:48:41,594] Trial 6 finished with value: 0.058651658849128395 and parameters: {'use_feature_gen': True, 'use_pca': False, 'pca_components': 20, 'learning_rate': 0.04945665442990347, 'num_leaves': 214, 'min_data_in_leaf': 28, 'feature_fraction': 0.8431561395248868, 'bagging_fraction': 0.6615101973044316, 'bagging_freq': 6, 'lambda_l1': 0.17106686742553048, 'lambda_l2': 0.1433718887906728, 'boosting_type': 'dart'}. Best is trial 4 with value: 0.05604852309513626.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 10-48-45
# Training until validation scores don't improve for 300 rounds
# [1000]	train's rmse: 0.338704	valid's rmse: 0.344104
# Early stopping, best iteration is:
# [1017]	train's rmse: 0.338633	valid's rmse: 0.344098
# Training until validation scores don't improve for 300 rounds
# [1000]	train's rmse: 0.33884	valid's rmse: 0.343199
# Early stopping, best iteration is:
# [962]	train's rmse: 0.339003	valid's rmse: 0.34318
# Training until validation scores don't improve for 300 rounds
# [1000]	train's rmse: 0.338928	valid's rmse: 0.342946
# Early stopping, best iteration is:
# [794]	train's rmse: 0.339856	valid's rmse: 0.342937
# Training until validation scores don't improve for 300 rounds13.6s]
# [1000]	train's rmse: 0.338854	valid's rmse: 0.342718
# Early stopping, best iteration is:
# [852]	train's rmse: 0.33955	valid's rmse: 0.342706
# Training until validation scores don't improve for 300 rounds13.6s   14.1s]
# [1000]	train's rmse: 0.338832	valid's rmse: 0.344357
# Early stopping, best iteration is:
# [960]	train's rmse: 0.339006	valid's rmse: 0.344335
# Training until validation scores don't improve for 300 rounds13.6s   14.1s   14.8s]
# [1000]	train's rmse: 0.339013	valid's rmse: 0.343166
# Early stopping, best iteration is:
# [928]	train's rmse: 0.339327	valid's rmse: 0.343138
# Training until validation scores don't improve for 300 rounds13.6s   14.1s   14.8s ///   14.6s]
# [1000]	train's rmse: 0.338785	valid's rmse: 0.344336
# Early stopping, best iteration is:
# [899]	train's rmse: 0.339225	valid's rmse: 0.344285
# Training until validation scores don't improve for 300 rounds13.6s   14.1s   14.8s ///   14.6s   14.7s]
# [1000]	train's rmse: 0.338764	valid's rmse: 0.344625
# Early stopping, best iteration is:
# [1400]	train's rmse: 0.337006	valid's rmse: 0.344549
# Training until validation scores don't improve for 300 rounds13.6s   14.1s   14.8s ///   14.6s   14.7s   18.1s]
# [1000]	train's rmse: 0.338921	valid's rmse: 0.342508
# Early stopping, best iteration is:
# [861]	train's rmse: 0.339526	valid's rmse: 0.342471
# Training until validation scores don't improve for 300 rounds13.6s   14.1s   14.8s ///   14.6s   14.7s   18.1s   13.9s]
# [1000]	train's rmse: 0.338663	valid's rmse: 0.344335
# Early stopping, best iteration is:
# [1172]	train's rmse: 0.337927	valid's rmse: 0.344289
# [I 2025-10-24 10:51:18,563] Trial 7 finished with value: 0.05618495105605834 and parameters: {'use_feature_gen': True, 'use_pca': True, 'pca_components': 5, 'learning_rate': 0.022778075949933623, 'num_leaves': 58, 'min_data_in_leaf': 70, 'feature_fraction': 0.7927722979740537, 'bagging_fraction': 0.6505819421030906, 'bagging_freq': 9, 'lambda_l1': 0.0039441578429872965, 'lambda_l2': 0.6441734110193609, 'boosting_type': 'gbdt'}. Best is trial 4 with value: 0.05604852309513626.
# ————————————————————————————————————————
# ✅ 当前结果将保存到: 2025-10-24 10-51-19
# [1000]	train's rmse: 0.338594	valid's rmse: 0.344958
# [2000]	train's rmse: 0.333928	valid's rmse: 0.344605
# [3000]	train's rmse: 0.329626	valid's rmse: 0.345051
# [4000]	train's rmse: 0.325388	valid's rmse: 0.345916
# [5000]	train's rmse: 0.322063	valid's rmse: 0.346519
# [6000]	train's rmse: 0.318667	valid's rmse: 0.347279
# [7000]	train's rmse: 0.315391	valid's rmse: 0.348071
# [8000]	train's rmse: 0.312375	valid's rmse: 0.348776
# [9000]	train's rmse: 0.309541	valid's rmse: 0.349514
# [10000]	train's rmse: 0.306525	valid's rmse: 0.350359
# [11000]	train's rmse: 0.303228	valid's rmse: 0.351185
# [12000]	train's rmse: 0.300596	valid's rmse: 0.35182
# [13000]	train's rmse: 0.298053	valid's rmse: 0.352541
# [14000]	train's rmse: 0.295637	valid's rmse: 0.353156
# [15000]	train's rmse: 0.293184	valid's rmse: 0.353849
# [1000]	train's rmse: 0.338899	valid's rmse: 0.343563]
# [2000]	train's rmse: 0.33419	valid's rmse: 0.343211
# [3000]	train's rmse: 0.32997	valid's rmse: 0.343591
# [4000]	train's rmse: 0.325688	valid's rmse: 0.344442
# [5000]	train's rmse: 0.322466	valid's rmse: 0.345085
# [6000]	train's rmse: 0.319064	valid's rmse: 0.345944
# [7000]	train's rmse: 0.315657	valid's rmse: 0.346666
# [8000]	train's rmse: 0.312592	valid's rmse: 0.347417
# [9000]	train's rmse: 0.309809	valid's rmse: 0.34815
# [10000]	train's rmse: 0.306924	valid's rmse: 0.348861
# [11000]	train's rmse: 0.303605	valid's rmse: 0.349747
# [12000]	train's rmse: 0.300978	valid's rmse: 0.350456
# [13000]	train's rmse: 0.298402	valid's rmse: 0.351089
# [14000]	train's rmse: 0.295972	valid's rmse: 0.351707
# [15000]	train's rmse: 0.293572	valid's rmse: 0.352435
# [1000]	train's rmse: 0.338834	valid's rmse: 0.343483 1828.0s]
# [2000]	train's rmse: 0.334127	valid's rmse: 0.342954
# [3000]	train's rmse: 0.329827	valid's rmse: 0.34361
# [4000]	train's rmse: 0.325492	valid's rmse: 0.344472
# [5000]	train's rmse: 0.3222	valid's rmse: 0.345117
# [6000]	train's rmse: 0.318779	valid's rmse: 0.345842
# [7000]	train's rmse: 0.315435	valid's rmse: 0.346673
# [8000]	train's rmse: 0.312299	valid's rmse: 0.34742
# [9000]	train's rmse: 0.309476	valid's rmse: 0.34815
# [10000]	train's rmse: 0.306554	valid's rmse: 0.348998
# [11000]	train's rmse: 0.303192	valid's rmse: 0.349861
# [12000]	train's rmse: 0.300592	valid's rmse: 0.350626
# [13000]	train's rmse: 0.297963	valid's rmse: 0.351366
# [14000]	train's rmse: 0.29563	valid's rmse: 0.352062
# [15000]	train's rmse: 0.29313	valid's rmse: 0.352716
# [1000]	train's rmse: 0.338778	valid's rmse: 0.343275 1828.0s 1813.8s]
# [2000]	train's rmse: 0.334083	valid's rmse: 0.342865
# [3000]	train's rmse: 0.329782	valid's rmse: 0.343421
# [4000]	train's rmse: 0.32545	valid's rmse: 0.344327
# [5000]	train's rmse: 0.322209	valid's rmse: 0.344955
# [6000]	train's rmse: 0.318789	valid's rmse: 0.345801
# [7000]	train's rmse: 0.315403	valid's rmse: 0.346597
# [8000]	train's rmse: 0.312265	valid's rmse: 0.347458
# [9000]	train's rmse: 0.309364	valid's rmse: 0.348236
# [10000]	train's rmse: 0.306438	valid's rmse: 0.349126
# [11000]	train's rmse: 0.303116	valid's rmse: 0.349994
# [12000]	train's rmse: 0.300533	valid's rmse: 0.350664
# [13000]	train's rmse: 0.297992	valid's rmse: 0.351385
# [14000]	train's rmse: 0.295574	valid's rmse: 0.352155
# [15000]	train's rmse: 0.293048	valid's rmse: 0.352927
# [1000]	train's rmse: 0.338703	valid's rmse: 0.344924 1828.0s 1813.8s 1820.8s]
# [2000]	train's rmse: 0.333994	valid's rmse: 0.344544
# [3000]	train's rmse: 0.32978	valid's rmse: 0.345056
# [4000]	train's rmse: 0.325532	valid's rmse: 0.345846
# [5000]	train's rmse: 0.322198	valid's rmse: 0.346409
# [6000]	train's rmse: 0.318813	valid's rmse: 0.347142
# [7000]	train's rmse: 0.315435	valid's rmse: 0.347884
# [8000]	train's rmse: 0.31236	valid's rmse: 0.34861
# [9000]	train's rmse: 0.309531	valid's rmse: 0.349424
# [10000]	train's rmse: 0.306567	valid's rmse: 0.350243
# [11000]	train's rmse: 0.303297	valid's rmse: 0.351195
# [12000]	train's rmse: 0.3007	valid's rmse: 0.351873
# [13000]	train's rmse: 0.298057	valid's rmse: 0.352621
# [14000]	train's rmse: 0.295589	valid's rmse: 0.35337
# [15000]	train's rmse: 0.293115	valid's rmse: 0.354119
# [1000]	train's rmse: 0.338907	valid's rmse: 0.344016 1828.0s 1813.8s 1820.8s 1822.7s]
# [2000]	train's rmse: 0.334163	valid's rmse: 0.343602
# [3000]	train's rmse: 0.329892	valid's rmse: 0.34409
# [4000]	train's rmse: 0.32565	valid's rmse: 0.344932
# [5000]	train's rmse: 0.322386	valid's rmse: 0.345574
# [6000]	train's rmse: 0.31892	valid's rmse: 0.346422
# [7000]	train's rmse: 0.315559	valid's rmse: 0.347157
# [8000]	train's rmse: 0.312419	valid's rmse: 0.347964
# [9000]	train's rmse: 0.309585	valid's rmse: 0.348729
# [10000]	train's rmse: 0.306631	valid's rmse: 0.349539
# [11000]	train's rmse: 0.303292	valid's rmse: 0.350428
# [12000]	train's rmse: 0.300657	valid's rmse: 0.351136
# [13000]	train's rmse: 0.298136	valid's rmse: 0.351885
# [14000]	train's rmse: 0.295746	valid's rmse: 0.352575
# [15000]	train's rmse: 0.293243	valid's rmse: 0.353293
# [W 2025-10-24 13:54:51,978] Trial 8 failed with parameters: {'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'learning_rate': 0.04470271994566001, 'num_leaves': 192, 'min_data_in_leaf': 79, 'feature_fraction': 0.8102328267360597, 'bagging_fraction': 0.8212406982029004, 'bagging_freq': 2, 'lambda_l1': 1.0416596589636642, 'lambda_l2': 0.0010992384601723694, 'boosting_type': 'dart'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "d:\Software\conda\envs\py39_tf\lib\site-packages\optuna\study\_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_43384\674254397.py", line 139, in objective
#     results = run_kfold_xgb(X, y, X_test, config, DIRS, K_FOLDS = 10, verbose = 0)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_43384\2787167921.py", line 168, in run_kfold_xgb
#     y_test_pred  = lgb_model.predict(x_test_new,  num_iteration=lgb_model.best_iteration)
#   File "d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py", line 4453, in predict
#     importance_type: str = "split",
#   File "d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py", line 1159, in predict
#     data=data,
#   File "d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py", line 1306, in __pred_for_np2d
#     out_num_preds = ctypes.c_int64(0)
#   File "d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py", line 1259, in __inner_predict_np2d
#     self,
# KeyboardInterrupt
# [W 2025-10-24 13:54:51,979] Trial 8 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 25
#      23     study.optimize(objective, n_trials = 3)
#      24 else:
# ---> 25     study.optimize(objective, n_trials = 200)
#      28 # 6. 打印最优结果
#      29 print("\n✅ 训练完成！")
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     frozen_trial = _run_trial(study, func, catch)
#     164 finally:
#     165     # The following line mitigates memory problems that can be occurred in some
#     166     # environments (e.g., services that use computing containers such as GitHub Actions).
#     167     # Please refer to the following PR for further details:
#     168     # https://github.com/optuna/optuna/pull/325.
#     169     if gc_after_trial:
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\optuna\study\_optimize.py:251, in _run_trial(study, func, catch)
#     244         assert False, "Should not reach."
#     246 if (
#     247     frozen_trial.state == TrialState.FAIL
#     248     and func_err is not None
#     249     and not isinstance(func_err, catch)
#     250 ):
# --> 251     raise func_err
#     252 return frozen_trial
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\optuna\study\_optimize.py:200, in _run_trial(study, func, catch)
#     198 with get_heartbeat_thread(trial._trial_id, study._storage):
#     199     try:
# --> 200         value_or_values = func(trial)
#     201     except exceptions.TrialPruned as e:
#     202         # TODO(mamu): Handle multi-objective cases.
#     203         state = TrialState.PRUNED
#
# Cell In[28], line 139, in objective(trial)
#     131     print("开始训练---------------------------")
#     133     # 准备流程---------------------------------------------------------------------------------------------------
# --> 139 results = run_kfold_xgb(X, y, X_test, config, DIRS, K_FOLDS = 10, verbose = 0)
#     140 config = results['config']
#     141 score = results['final_score']
#
# Cell In[31], line 168, in run_kfold_xgb(features_train, target_train, features_test, config, DIRS, K_FOLDS, verbose)
#     166 y_train_pred = lgb_model.predict(x_train_new, num_iteration=lgb_model.best_iteration)
#     167 y_val_pred   = lgb_model.predict(x_val_new,   num_iteration=lgb_model.best_iteration)
# --> 168 y_test_pred  = lgb_model.predict(x_test_new,  num_iteration=lgb_model.best_iteration)
#     179 # 9. 逆变换
#     180 y_train      = yeo.inverse_transform(y_train.reshape(-1, 1)).squeeze()
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py:4453, in predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features, **kwargs)
#    4414     """Evaluate for validation data.
#    4415
#    4416     Parameters
#    (...)
#    4440         List with (validation_dataset_name, eval_name, eval_result, is_higher_better) tuples.
#    4441     """
#    4442     return [
#    4443         item
#    4444         for i in range(1, self.__num_dataset)
#    4445         for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)
#    4446     ]
#    4448 def save_model(
#    4449     self,
#    4450     filename: Union[str, Path],
#    4451     num_iteration: Optional[int] = None,
#    4452     start_iteration: int = 0,
# -> 4453     importance_type: str = "split",
#    4454 ) -> "Booster":
#    4455     """Save Booster to file.
#    4456
#    4457     Parameters
#    (...)
#    4475         Returns self.
#    4476     """
#    4477     if num_iteration is None:
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py:1159, in predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features)
#    1149     _safe_call(
#    1150         _LIB.LGBM_BoosterValidateFeatureNames(
#    1151             self._handle,
#    (...)
#    1154         )
#    1155     )
#    1157 if isinstance(data, pd_DataFrame):
#    1158     data = _data_from_pandas(
# -> 1159         data=data,
#    1160         feature_name="auto",
#    1161         categorical_feature="auto",
#    1162         pandas_categorical=self.pandas_categorical,
#    1163     )[0]
#    1165 predict_type = _C_API_PREDICT_NORMAL
#    1166 if raw_score:
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py:1306, in __pred_for_np2d(self, mat, start_iteration, num_iteration, predict_type)
#    1304 elif len(preds.shape) != 1 or len(preds) != n_preds:
#    1305     raise ValueError("Wrong length of pre-allocated predict array")
# -> 1306 out_num_preds = ctypes.c_int64(0)
#    1307 _safe_call(
#    1308     _LIB.LGBM_BoosterPredictForMat(
#    1309         self._handle,
#    (...)
#    1321     )
#    1322 )
#    1323 if n_preds != out_num_preds.value:
#
# File d:\Software\conda\envs\py39_tf\lib\site-packages\lightgbm\basic.py:1259, in __inner_predict_np2d(self, mat, start_iteration, num_iteration, predict_type, preds)
#    1255             raise ValueError(f"Length of predict result ({preds.size}) cannot be divide nrow ({nrow})")
#    1256     return preds
#    1258 def __get_num_preds(
# -> 1259     self,
#    1260     start_iteration: int,
#    1261     num_iteration: int,
#    1262     nrow: int,
#    1263     predict_type: int,
#    1264 ) -> int:
#    1265     """Get size of prediction result."""
#    1266     if nrow > _MAX_INT32:
#
# KeyboardInterrupt:

# %% [markdown]
# # 管理数据库信息

# %%
# 查询数据库详细数据

storage_url = "mysql+pymysql://user1:123456@10.162.147.95:3306/kaggle_melting_point_optuna"

studies = optuna.study.get_all_study_summaries(storage=storage_url)

if not studies:
    print("❌ 当前数据库里无 study")
else:
    print("✅ 数据库中的 study 列表:")
    for s in studies:

        print("-", s.study_name)

        study = optuna.load_study(study_name=s.study_name, storage=storage_url)

        print("         Trials:")
        for trial in study.trials:
            host = trial.user_attrs.get("host") or "unknown"
            ip = trial.user_attrs.get("ip") or "unknown"
            value = f"{trial.value:.10f}" if trial.value is not None else "None"

            print(
                f"    Trial {trial.number:4d}: "
                f"host={host:<16}, ip={ip:<15}, "
                f"value={value:<15}, params={trial.params}"
            )

        print("    总 trial 数量:", len(study.trials))
        print("=" * 100)
# Out:
# ✅ 数据库中的 study 列表:
# - optuna_task1
#          Trials:
#     Trial    0: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': '0.75*mean', 'train_max_depth': 6, 'train_eta': 0.14963770710824598}
#     Trial    1: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 42, 'selector_device': 'cuda', 'selector_threshold': '1.25*mean', 'train_max_depth': 7, 'train_eta': 0.018021464633564754}
#     Trial    2: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 8, 'train_eta': 0.021659776125338565}
#     Trial    3: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': True, 'use_feature_gen': False, 'use_pca': True, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': '1.25*mean', 'train_max_depth': 4, 'train_eta': 0.23918065062107188}
#     Trial    4: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 42, 'selector_device': 'cuda', 'selector_threshold': '1.25*mean', 'train_max_depth': 6, 'train_eta': 0.10392736979117173}
#     Trial    5: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': '0.5*mean', 'train_max_depth': 10, 'train_eta': 0.24138275928502126}
#     Trial    6: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': True, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cuda', 'selector_threshold': 'mean', 'train_max_depth': 6, 'train_eta': 0.06282544238599601}
#     Trial    7: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 2025, 'selector_device': 'cuda', 'selector_threshold': '0.75*mean', 'train_max_depth': 10, 'train_eta': 0.017725574116549923}
#     Trial    8: host=hao-2           , ip=192.168.40.1   , value=17.8499293284  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 6, 'train_eta': 0.01368700824230773}
#     Trial    9: host=hao-2           , ip=192.168.40.1   , value=17.9953215741  , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cuda', 'selector_threshold': '0.75*mean', 'train_max_depth': 4, 'train_eta': 0.05053010910637573}
#     Trial   10: host=hao-2           , ip=192.168.40.1   , value=18.9248106287  , params={'remove_dup_smiles': True, 'use_feature_gen': False, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': '0.5*mean', 'train_max_depth': 4, 'train_eta': 0.026729074261343022}
#     Trial   11: host=hao-2           , ip=192.168.40.1   , value=18.4746024423  , params={'remove_dup_smiles': False, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': '0.75*mean', 'train_max_depth': 12, 'train_eta': 0.0955937800637472}
#     Trial   12: host=hao-2           , ip=192.168.40.1   , value=18.8439245798  , params={'remove_dup_smiles': True, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 5, 'train_eta': 0.01844230194954457}
#     Trial   13: host=hao-2           , ip=192.168.40.1   , value=18.5824856744  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 11, 'train_eta': 0.013329388592334063}
#     Trial   14: host=hao-2           , ip=192.168.40.1   , value=17.5563208849  , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 8, 'train_eta': 0.013678962412610542}
#     Trial   15: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': '0.5*mean', 'train_max_depth': 6, 'train_eta': 0.03616840082637632}
#     Trial   16: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 42, 'selector_device': 'cuda', 'selector_threshold': '0.75*mean', 'train_max_depth': 9, 'train_eta': 0.03020978585855579}
#     Trial   17: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 42, 'selector_device': 'cuda', 'selector_threshold': 'mean', 'train_max_depth': 9, 'train_eta': 0.06269871406279931}
#     Trial   18: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=18.0383829748  , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cuda', 'selector_threshold': '0.5*mean', 'train_max_depth': 10, 'train_eta': 0.09158730675112933}
#     Trial   19: host=hao-2           , ip=192.168.40.1   , value=18.0853127800  , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': '1.25*mean', 'train_max_depth': 9, 'train_eta': 0.045732428074001644}
#     Trial   20: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=18.2934244056  , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': '0.75*mean', 'train_max_depth': 5, 'train_eta': 0.01810149024614987}
#     Trial   21: host=hao-2           , ip=192.168.40.1   , value=17.9751673013  , params={'remove_dup_smiles': False, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': '0.75*mean', 'train_max_depth': 4, 'train_eta': 0.06743144217230011}
#     Trial   22: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=18.5058846760  , params={'remove_dup_smiles': False, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cuda', 'selector_threshold': '1.25*mean', 'train_max_depth': 8, 'train_eta': 0.2193719583768128}
#     Trial   23: host=hao-2           , ip=192.168.40.1   , value=18.0255023076  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 42, 'selector_device': 'cuda', 'selector_threshold': 'mean', 'train_max_depth': 7, 'train_eta': 0.01061463707842147}
#     Trial   24: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=17.8360657244  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 7, 'train_eta': 0.01024884269234489}
#     Trial   25: host=hao-2           , ip=192.168.40.1   , value=17.7623024455  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 7, 'train_eta': 0.02880197004042992}
#     Trial   26: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=17.9105346242  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 8, 'train_eta': 0.028795735946134868}
#     Trial   27: host=hao-2           , ip=192.168.40.1   , value=17.7254744419  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 9, 'train_eta': 0.027734152778904956}
#     Trial   28: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=17.6955375743  , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 9, 'train_eta': 0.031257959966538636}
#     Trial   29: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 10, 'train_eta': 0.020728885589285505}
#     Trial   30: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=18.8729711754  , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cuda', 'selector_threshold': '1.25*mean', 'train_max_depth': 9, 'train_eta': 0.29698899022302994}
#     Trial   31: host=DESKTOP-M056LUV , ip=192.168.217.1  , value=18.0806782843  , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': '0.5*mean', 'train_max_depth': 11, 'train_eta': 0.018642202135939336}
#     Trial   32: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': False, 'use_feature_gen': True, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 10, 'train_eta': 0.044473160758285384}
#     总 trial 数量: 33
# ====================================================================================================
# - test
#          Trials:
#     Trial    0: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': True, 'use_feature_gen': True, 'use_pca': True, 'selector_random_state': 2025, 'selector_device': 'cuda', 'selector_threshold': '0.5*mean', 'train_max_depth': 10, 'train_eta': 0.04410160779890175}
#     Trial    1: host=DESKTOP-M056LUV , ip=198.18.0.1     , value=49.1580939636  , params={'remove_dup_smiles': False, 'use_feature_gen': False, 'use_pca': True, 'selector_random_state': 42, 'selector_device': 'cuda', 'selector_threshold': '0.5*mean', 'train_max_depth': 4, 'train_eta': 0.04105647603066798}
#     Trial    2: host=unknown         , ip=unknown        , value=None           , params={'remove_dup_smiles': True, 'use_feature_gen': False, 'use_pca': False, 'selector_random_state': 2025, 'selector_device': 'cpu', 'selector_threshold': 'mean', 'train_max_depth': 4, 'train_eta': 0.04449261200509654}
#     Trial    3: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': True, 'pca_components': 10}
#     总 trial 数量: 4
# ====================================================================================================
# - test2
#          Trials:
#     Trial    0: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0.25*mean', 'train_max_depth': 9, 'train_eta': 0.01735336835694381}
#     Trial    1: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': '0.75*mean', 'train_max_depth': 9, 'train_eta': 0.022792661238939513}
#     Trial    2: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0.75*mean', 'train_max_depth': 9, 'train_eta': 0.0929835670700044}
#     Trial    3: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 10, 'train_eta': 0.04175646572863315}
#     Trial    4: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 3, 'train_eta': 0.02703175447504527}
#     Trial    5: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': 'mean', 'train_max_depth': 12, 'train_eta': 0.20196937487304478}
#     Trial    6: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': True, 'pca_components': 15, 'selector_threshold': '0.75*mean', 'train_max_depth': 6, 'train_eta': 0.15729356101645853}
#     Trial    7: host=hao-2           , ip=192.168.40.1   , value=0.0937739187   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0.5*mean', 'train_max_depth': 10, 'train_eta': 0.026998403225701243}
#     Trial    8: host=hao-2           , ip=192.168.40.1   , value=0.0820323904   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.5*mean', 'train_max_depth': 5, 'train_eta': 0.06796357465007441}
#     Trial    9: host=hao-2           , ip=192.168.40.1   , value=0.0933040149   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.2593091513357435}
#     总 trial 数量: 10
# ====================================================================================================
# - Predicting Road Accident Risk
#          Trials:
#     Trial    0: host=hao-2           , ip=192.168.40.1   , value=0.0616985820   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': 'mean', 'train_max_depth': 11, 'train_eta': 0.1343165303132418}
#     Trial    1: host=hao-2           , ip=192.168.40.1   , value=0.0561359815   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.022101706430071286}
#     Trial    2: host=hao-2           , ip=192.168.40.1   , value=0.0568511314   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 20, 'selector_threshold': 'mean', 'train_max_depth': 5, 'train_eta': 0.030061906417876233}
#     Trial    3: host=hao-2           , ip=192.168.40.1   , value=0.0990395124   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': 'mean', 'train_max_depth': 10, 'train_eta': 0.11759367394515066}
#     Trial    4: host=hao-2           , ip=192.168.40.1   , value=0.0566365823   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 20, 'selector_threshold': '0.25*mean', 'train_max_depth': 10, 'train_eta': 0.15681166001402455}
#     Trial    5: host=hao-2           , ip=192.168.40.1   , value=0.0563055524   , params={'use_feature_gen': True, 'use_pca': True, 'pca_components': 15, 'selector_threshold': 'mean', 'train_max_depth': 7, 'train_eta': 0.03128344823061561}
#     Trial    6: host=hao-2           , ip=192.168.40.1   , value=0.0612291683   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.5*mean', 'train_max_depth': 12, 'train_eta': 0.01665208835108825}
#     Trial    7: host=hao-2           , ip=192.168.40.1   , value=0.0614007533   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 15, 'selector_threshold': '0.75*mean', 'train_max_depth': 10, 'train_eta': 0.021498647599234273}
#     Trial    8: host=hao-2           , ip=192.168.40.1   , value=0.0564203923   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 20, 'selector_threshold': '0.5*mean', 'train_max_depth': 8, 'train_eta': 0.11540712338703248}
#     Trial    9: host=hao-2           , ip=192.168.40.1   , value=0.0619782618   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': 'mean', 'train_max_depth': 7, 'train_eta': 0.2653548608576974}
#     Trial   10: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 3, 'train_eta': 0.010889622798107575}
#     Trial   11: host=hao-2           , ip=192.168.40.1   , value=0.0563006313   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 3, 'train_eta': 0.010090888129942048}
#     Trial   12: host=hao-2           , ip=192.168.40.1   , value=0.0562983107   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 3, 'train_eta': 0.010398400521342504}
#     Trial   13: host=hao-2           , ip=192.168.40.1   , value=0.0562985084   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 3, 'train_eta': 0.010031843010327147}
#     Trial   14: host=hao-2           , ip=192.168.40.1   , value=0.0561911604   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 5, 'train_eta': 0.061959157253884393}
#     Trial   15: host=hao-2           , ip=192.168.40.1   , value=0.0561981180   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 5, 'train_eta': 0.05867067117716805}
#     Trial   16: host=hao-2           , ip=192.168.40.1   , value=0.0561914321   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 5, 'train_eta': 0.06252183479882706}
#     Trial   17: host=hao-2           , ip=192.168.40.1   , value=0.0562778768   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0.75*mean', 'train_max_depth': 6, 'train_eta': 0.040484398511809475}
#     Trial   18: host=hao-2           , ip=192.168.40.1   , value=0.0563629645   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.25*mean', 'train_max_depth': 8, 'train_eta': 0.07687002639155492}
#     Trial   19: host=hao-2           , ip=192.168.40.1   , value=0.0562123664   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 4, 'train_eta': 0.019134601989629855}
#     Trial   20: host=hao-2           , ip=192.168.40.1   , value=0.0561450966   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.0434993340541247}
#     Trial   21: host=hao-2           , ip=192.168.40.1   , value=0.0561441084   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.036818420928244826}
#     Trial   22: host=hao-2           , ip=192.168.40.1   , value=0.0561417503   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.040454204290225365}
#     Trial   23: host=hao-2           , ip=192.168.40.1   , value=0.0561362620   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.025721065979479384}
#     Trial   24: host=hao-2           , ip=192.168.40.1   , value=0.0561213100   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.022554824684887266}
#     Trial   25: host=hao-2           , ip=192.168.40.1   , value=0.0563357744   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0.5*mean', 'train_max_depth': 9, 'train_eta': 0.02442408095591174}
#     Trial   26: host=hao-2           , ip=192.168.40.1   , value=0.0562763669   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0.75*mean', 'train_max_depth': 8, 'train_eta': 0.014639135230786119}
#     Trial   27: host=hao-2           , ip=192.168.40.1   , value=0.0560947172   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.013860886523398041}
#     Trial   28: host=hao-2           , ip=192.168.40.1   , value=0.0563446013   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.25*mean', 'train_max_depth': 9, 'train_eta': 0.014502244122916228}
#     Trial   29: host=hao-2           , ip=192.168.40.1   , value=0.0560918589   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.014140140965016462}
#     Trial   30: host=hao-2           , ip=192.168.40.1   , value=0.0561809216   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.013234262879345274}
#     Trial   31: host=hao-2           , ip=192.168.40.1   , value=0.0560934405   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.019108712876218598}
#     Trial   32: host=hao-2           , ip=192.168.40.1   , value=0.0560897185   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01687052492598196}
#     Trial   33: host=hao-2           , ip=192.168.40.1   , value=0.0560940140   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.017605968841057733}
#     Trial   34: host=hao-2           , ip=192.168.40.1   , value=0.0560922161   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01770619112073725}
#     Trial   35: host=hao-2           , ip=192.168.40.1   , value=0.0560892002   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01205228754278379}
#     Trial   36: host=hao-2           , ip=192.168.40.1   , value=0.0562713493   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.25*mean', 'train_max_depth': 8, 'train_eta': 0.012948563635902298}
#     Trial   37: host=hao-2           , ip=192.168.40.1   , value=0.0990328433   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': 'mean', 'train_max_depth': 9, 'train_eta': 0.01213164345163444}
#     Trial   38: host=hao-2           , ip=192.168.40.1   , value=0.0562709157   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 15, 'selector_threshold': '0.5*mean', 'train_max_depth': 7, 'train_eta': 0.02822901674662921}
#     Trial   39: host=hao-2           , ip=192.168.40.1   , value=0.0609089311   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': '0.75*mean', 'train_max_depth': 11, 'train_eta': 0.015873429078579627}
#     Trial   40: host=hao-2           , ip=192.168.40.1   , value=0.0561551540   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.011952573904944095}
#     Trial   41: host=hao-2           , ip=192.168.40.1   , value=0.0990326574   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': 'mean', 'train_max_depth': 4, 'train_eta': 0.01883563641811797}
#     Trial   42: host=hao-2           , ip=192.168.40.1   , value=0.0560980804   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.020385740697186145}
#     Trial   43: host=hao-2           , ip=192.168.40.1   , value=0.0561137592   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.03276384729569395}
#     Trial   44: host=hao-2           , ip=192.168.40.1   , value=0.0560976310   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.018184509625602356}
#     Trial   45: host=hao-2           , ip=192.168.40.1   , value=0.0561882784   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.016450605851033608}
#     Trial   46: host=hao-2           , ip=192.168.40.1   , value=0.0561423777   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.021912501231580846}
#     Trial   47: host=hao-2           , ip=192.168.40.1   , value=0.0611064088   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.5*mean', 'train_max_depth': 6, 'train_eta': 0.011228111778700242}
#     Trial   48: host=hao-2           , ip=192.168.40.1   , value=0.0560946720   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01629760538821967}
#     Trial   49: host=hao-2           , ip=192.168.40.1   , value=0.0566451254   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': '0*mean', 'train_max_depth': 5, 'train_eta': 0.2563548019561122}
#     Trial   50: host=hao-2           , ip=192.168.40.1   , value=0.0990397192   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': 'mean', 'train_max_depth': 10, 'train_eta': 0.09715667045555489}
#     Trial   51: host=hao-2           , ip=192.168.40.1   , value=0.0563278032   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.25*mean', 'train_max_depth': 5, 'train_eta': 0.02761659490116216}
#     Trial   52: host=hao-2           , ip=192.168.40.1   , value=0.0560936278   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.017174592304338005}
#     Trial   53: host=hao-2           , ip=192.168.40.1   , value=0.0560902772   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01113315352486295}
#     Trial   54: host=hao-2           , ip=192.168.40.1   , value=0.0561552665   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.011322672718336884}
#     Trial   55: host=hao-2           , ip=192.168.40.1   , value=0.0560820987   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010739435241885933}
#     Trial   56: host=hao-2           , ip=192.168.40.1   , value=0.0560849648   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.011247568365800566}
#     Trial   57: host=hao-2           , ip=192.168.40.1   , value=0.0613523680   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 15, 'selector_threshold': '0.75*mean', 'train_max_depth': 9, 'train_eta': 0.010497959924244862}
#     Trial   58: host=hao-2           , ip=192.168.40.1   , value=0.0560807452   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010231014599101425}
#     Trial   59: host=hao-2           , ip=192.168.40.1   , value=0.0560856251   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01000276826076782}
#     Trial   60: host=hao-2           , ip=192.168.40.1   , value=0.0560837601   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010070927083825062}
#     Trial   61: host=hao-2           , ip=192.168.40.1   , value=0.0562570215   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 10, 'train_eta': 0.01002955589456064}
#     Trial   62: host=hao-2           , ip=192.168.40.1   , value=0.0560864805   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.012165013735239575}
#     Trial   63: host=hao-2           , ip=192.168.40.1   , value=0.0560863257   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.012650912172330045}
#     Trial   64: host=hao-2           , ip=192.168.40.1   , value=0.0560865564   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.013187504951575519}
#     Trial   65: host=hao-2           , ip=192.168.40.1   , value=0.0561351781   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.010118270919810256}
#     Trial   66: host=hao-2           , ip=192.168.40.1   , value=0.0611045598   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.5*mean', 'train_max_depth': 8, 'train_eta': 0.01454274747363895}
#     Trial   67: host=hao-2           , ip=192.168.40.1   , value=0.0562280222   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.012289197760237238}
#     Trial   68: host=hao-2           , ip=192.168.40.1   , value=0.0560823617   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010989450102966593}
#     Trial   69: host=hao-2           , ip=192.168.40.1   , value=0.0562752582   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.25*mean', 'train_max_depth': 8, 'train_eta': 0.014908057964219044}
#     Trial   70: host=hao-2           , ip=192.168.40.1   , value=0.0615040187   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 10, 'selector_threshold': '0.75*mean', 'train_max_depth': 9, 'train_eta': 0.01109592471026608}
#     Trial   71: host=hao-2           , ip=192.168.40.1   , value=0.0567036504   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.18190179371843868}
#     Trial   72: host=hao-2           , ip=192.168.40.1   , value=0.0560877658   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.012986145566684093}
#     Trial   73: host=hao-2           , ip=192.168.40.1   , value=0.0560842235   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010082081770008983}
#     Trial   74: host=hao-2           , ip=192.168.40.1   , value=0.0561365344   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.0108340139529138}
#     Trial   75: host=hao-2           , ip=192.168.40.1   , value=0.0560822787   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010122857297054947}
#     Trial   76: host=hao-2           , ip=192.168.40.1   , value=0.0560823039   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010027363633745049}
#     Trial   77: host=hao-2           , ip=192.168.40.1   , value=0.0990332526   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': 'mean', 'train_max_depth': 9, 'train_eta': 0.013815661358234248}
#     Trial   78: host=hao-2           , ip=192.168.40.1   , value=0.0561176907   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.011304129212841905}
#     Trial   79: host=hao-2           , ip=192.168.40.1   , value=0.0561524933   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.015312173207531183}
#     Trial   80: host=hao-2           , ip=192.168.40.1   , value=0.0564859812   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 10, 'train_eta': 0.0538030843470158}
#     Trial   81: host=hao-2           , ip=192.168.40.1   , value=0.0560874249   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.011903518763004628}
#     Trial   82: host=hao-2           , ip=192.168.40.1   , value=0.0560835492   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010353016016998267}
#     Trial   83: host=hao-2           , ip=192.168.40.1   , value=0.0560841022   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010034861781243626}
#     Trial   84: host=hao-2           , ip=192.168.40.1   , value=0.0560876083   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.013836229681304792}
#     Trial   85: host=hao-2           , ip=192.168.40.1   , value=0.0561345543   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.010150112007473355}
#     Trial   86: host=hao-2           , ip=192.168.40.1   , value=0.0611033707   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0.5*mean', 'train_max_depth': 8, 'train_eta': 0.012869557543294491}
#     Trial   87: host=hao-2           , ip=192.168.40.1   , value=0.0561399781   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.011066644516022165}
#     Trial   88: host=hao-2           , ip=192.168.40.1   , value=0.0561005166   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.012088305595413443}
#     Trial   89: host=hao-2           , ip=192.168.40.1   , value=0.0563583691   , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 20, 'selector_threshold': '0.25*mean', 'train_max_depth': 9, 'train_eta': 0.01072356803388922}
#     Trial   90: host=hao-2           , ip=192.168.40.1   , value=0.0560422256   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.015572238646361687}
#     Trial   91: host=hao-2           , ip=192.168.40.1   , value=0.0562675090   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0.75*mean', 'train_max_depth': 7, 'train_eta': 0.01574258630581579}
#     Trial   92: host=hao-2           , ip=192.168.40.1   , value=0.0560360825   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01003693126867291}
#     Trial   93: host=hao-2           , ip=192.168.40.1   , value=0.0560383724   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.011715485938149221}
#     Trial   94: host=hao-2           , ip=192.168.40.1   , value=0.0560388996   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.013744147165911458}
#     Trial   95: host=hao-2           , ip=192.168.40.1   , value=0.0560410031   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.013739666231527916}
#     Trial   96: host=hao-2           , ip=192.168.40.1   , value=0.0560439496   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.020303930472277753}
#     Trial   97: host=hao-2           , ip=192.168.40.1   , value=0.0616364753   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 5, 'selector_threshold': 'mean', 'train_max_depth': 6, 'train_eta': 0.02026807225008075}
#     Trial   98: host=hao-2           , ip=192.168.40.1   , value=0.0560366712   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.013905865825033602}
#     Trial   99: host=hao-2           , ip=192.168.40.1   , value=0.0560375350   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.014097558668590747}
#     Trial  100: host=hao-2           , ip=192.168.40.1   , value=0.0560421851   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.015326461165906732}
#     Trial  101: host=hao-2           , ip=192.168.40.1   , value=0.0560972704   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.023756443747756126}
#     Trial  102: host=hao-2           , ip=192.168.40.1   , value=0.0560374233   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01385604526667623}
#     Trial  103: host=hao-2           , ip=192.168.40.1   , value=0.0560432398   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.019842699170398694}
#     Trial  104: host=hao-2           , ip=192.168.40.1   , value=0.0560402694   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01965325182926577}
#     Trial  105: host=hao-2           , ip=192.168.40.1   , value=0.0560423505   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.016963851265887394}
#     Trial  106: host=hao-2           , ip=192.168.40.1   , value=0.0560416359   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.017380917586134022}
#     Trial  107: host=hao-2           , ip=192.168.40.1   , value=0.0560933920   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.015067688720828112}
#     Trial  108: host=hao-2           , ip=192.168.40.1   , value=0.0561139486   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.013910312241675266}
#     Trial  109: host=hao-2           , ip=192.168.40.1   , value=0.0616340993   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0.5*mean', 'train_max_depth': 6, 'train_eta': 0.018749906955795675}
#     Trial  110: host=hao-2           , ip=192.168.40.1   , value=0.0560417474   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.016213135220833272}
#     Trial  111: host=hao-2           , ip=192.168.40.1   , value=0.0560418162   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.016636092678719277}
#     Trial  112: host=hao-2           , ip=192.168.40.1   , value=0.0560367756   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.0170987703176757}
#     Trial  113: host=hao-2           , ip=192.168.40.1   , value=0.0560459577   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.018350855235865944}
#     Trial  114: host=hao-2           , ip=192.168.40.1   , value=0.0560980411   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.022263423224220372}
#     Trial  115: host=hao-2           , ip=192.168.40.1   , value=0.0560413717   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.0168481278156546}
#     Trial  116: host=hao-2           , ip=192.168.40.1   , value=0.0562347815   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0.25*mean', 'train_max_depth': 7, 'train_eta': 0.013656419417219899}
#     Trial  117: host=hao-2           , ip=192.168.40.1   , value=0.0560402324   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.014593618083706072}
#     Trial  118: host=hao-2           , ip=192.168.40.1   , value=0.0560933168   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.017388767727502863}
#     Trial  119: host=hao-2           , ip=192.168.40.1   , value=0.0616326394   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0.75*mean', 'train_max_depth': 7, 'train_eta': 0.014473298752743568}
#     Trial  120: host=hao-2           , ip=192.168.40.1   , value=0.0560453537   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.025707814822688323}
#     Trial  121: host=hao-2           , ip=192.168.40.1   , value=0.0616311203   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': 'mean', 'train_max_depth': 7, 'train_eta': 0.013252214460828214}
#     Trial  122: host=hao-2           , ip=192.168.40.1   , value=0.0560419713   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.016150848851234346}
#     Trial  123: host=hao-2           , ip=192.168.40.1   , value=0.0560422015   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.017903741406127844}
#     Trial  124: host=hao-2           , ip=192.168.40.1   , value=0.0560913179   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.014625127369038671}
#     Trial  125: host=hao-2           , ip=192.168.40.1   , value=0.0560412197   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.021401134932567532}
#     Trial  126: host=hao-2           , ip=192.168.40.1   , value=0.0560572770   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.03164722157715209}
#     Trial  127: host=hao-2           , ip=192.168.40.1   , value=0.0560456801   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.0217953512974477}
#     Trial  128: host=hao-2           , ip=192.168.40.1   , value=0.0561330683   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.012641075198131768}
#     Trial  129: host=hao-2           , ip=192.168.40.1   , value=0.0569792144   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 12, 'train_eta': 0.01912287926651241}
#     Trial  130: host=hao-2           , ip=192.168.40.1   , value=0.0560476314   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.02359342549069225}
#     Trial  131: host=hao-2           , ip=192.168.40.1   , value=0.0560358151   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.012063545512670167}
#     Trial  132: host=hao-2           , ip=192.168.40.1   , value=0.0560368835   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.012202494763303755}
#     Trial  133: host=hao-2           , ip=192.168.40.1   , value=0.0560329560   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.011934310002774725}
#     Trial  134: host=hao-2           , ip=192.168.40.1   , value=0.0560353571   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01167835437319773}
#     Trial  135: host=hao-2           , ip=192.168.40.1   , value=0.0560357477   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.011891717769780158}
#     Trial  136: host=hao-2           , ip=192.168.40.1   , value=0.0560361319   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.011742239837380923}
#     Trial  137: host=hao-2           , ip=192.168.40.1   , value=0.0560932113   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 15, 'selector_threshold': '0*mean', 'train_max_depth': 6, 'train_eta': 0.011880751459403448}
# ...
#     Trial  218: host=hao-2           , ip=192.168.40.1   , value=0.0560381733   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.012375518879420575}
#     Trial  219: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.5*mean', 'train_max_depth': 7, 'train_eta': 0.010944409562554866}
#     Trial  220: host=hao-2           , ip=192.168.40.1   , value=0.0564643532   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.5*mean', 'train_max_depth': 11, 'train_eta': 0.011309473543217947}
#     Trial  221: host=hao-2           , ip=192.168.40.1   , value=0.0560378767   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.01227042604338162}
#     Trial  222: host=hao-2           , ip=192.168.40.1   , value=0.0560242997   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.011165985939033264}
#     Trial  223: host=hao-2           , ip=192.168.40.1   , value=0.0560330252   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01084385259951031}
#     Trial  224: host=hao-2           , ip=192.168.40.1   , value=0.0560299311   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01098146714820657}
#     Trial  225: host=hao-2           , ip=192.168.40.1   , value=0.0560362322   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 7, 'train_eta': 0.010012765565898814}
#     Trial  226: host=hao-2           , ip=192.168.40.1   , value=0.0560300726   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01125638734452253}
#     Trial  227: host=hao-2           , ip=192.168.40.1   , value=0.0560325091   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.011515747323230205}
#     Trial  228: host=hao-2           , ip=192.168.40.1   , value=0.0560304438   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010636571039153535}
#     Trial  229: host=hao-2           , ip=192.168.40.1   , value=0.0560305750   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010631179444657895}
#     Trial  230: host=hao-2           , ip=192.168.40.1   , value=0.0560273638   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010619222408571537}
#     Trial  231: host=hao-2           , ip=192.168.40.1   , value=0.0562442806   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.25*mean', 'train_max_depth': 8, 'train_eta': 0.010769955542928004}
#     Trial  232: host=hao-2           , ip=192.168.40.1   , value=0.0560248380   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010615932888917191}
#     Trial  233: host=hao-2           , ip=192.168.40.1   , value=0.0560267398   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010020796912010044}
#     Trial  234: host=hao-2           , ip=192.168.40.1   , value=0.0560255327   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01007018818959843}
#     Trial  235: host=hao-2           , ip=192.168.40.1   , value=0.0560282366   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010073370027040134}
#     Trial  236: host=hao-2           , ip=192.168.40.1   , value=0.0560264833   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010195563607476444}
#     Trial  237: host=hao-2           , ip=192.168.40.1   , value=0.0560289821   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010459695293160928}
#     Trial  238: host=hao-2           , ip=192.168.40.1   , value=0.0560295746   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010090842580461532}
#     Trial  239: host=hao-2           , ip=192.168.40.1   , value=0.0616362030   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.75*mean', 'train_max_depth': 8, 'train_eta': 0.010013042206486088}
#     Trial  240: host=hao-2           , ip=192.168.40.1   , value=0.0560286079   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01001905935097431}
#     Trial  241: host=hao-2           , ip=192.168.40.1   , value=0.0560260612   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010253128268708021}
#     Trial  242: host=hao-2           , ip=192.168.40.1   , value=0.0560275046   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010092483458597387}
#     Trial  243: host=hao-2           , ip=192.168.40.1   , value=0.0560292383   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010019757265910773}
#     Trial  244: host=hao-2           , ip=192.168.40.1   , value=0.0560262460   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010018735846301962}
#     Trial  245: host=hao-2           , ip=192.168.40.1   , value=0.0560276322   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010004745031182346}
#     Trial  246: host=hao-2           , ip=192.168.40.1   , value=0.0560278919   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01006293287914125}
#     Trial  247: host=hao-2           , ip=192.168.40.1   , value=0.0560308374   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010142802870893579}
#     Trial  248: host=hao-2           , ip=192.168.40.1   , value=0.0560282337   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010274816796220566}
#     Trial  249: host=hao-2           , ip=192.168.40.1   , value=0.0616359806   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': 'mean', 'train_max_depth': 8, 'train_eta': 0.010180981731675483}
#     Trial  250: host=hao-2           , ip=192.168.40.1   , value=0.0560257105   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01004019011584042}
#     Trial  251: host=hao-2           , ip=192.168.40.1   , value=0.0560262260   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010017055534153307}
#     Trial  252: host=hao-2           , ip=192.168.40.1   , value=0.0560258858   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010029286607704753}
#     Trial  253: host=hao-2           , ip=192.168.40.1   , value=0.0560274394   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010120973820757112}
#     Trial  254: host=hao-2           , ip=192.168.40.1   , value=0.0560265029   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01005286333818714}
#     Trial  255: host=hao-2           , ip=192.168.40.1   , value=0.0560273859   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010055138412507046}
#     Trial  256: host=hao-2           , ip=192.168.40.1   , value=0.0560274949   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010045818705700343}
#     Trial  257: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010056876956405733}
#     Trial  258: host=hao-2           , ip=192.168.40.1   , value=0.0560973955   , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010087026618655027}
#     Trial  259: host=hao-2           , ip=192.168.40.1   , value=0.0560287030   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01000320340514155}
#     Trial  260: host=hao-2           , ip=192.168.40.1   , value=0.0560276548   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010057481323574034}
#     Trial  261: host=hao-2           , ip=192.168.40.1   , value=0.0560276072   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010019455139311453}
#     Trial  262: host=hao-2           , ip=192.168.40.1   , value=0.0616366038   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.5*mean', 'train_max_depth': 8, 'train_eta': 0.010021067074471496}
#     Trial  263: host=hao-2           , ip=192.168.40.1   , value=0.0560306966   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010174444879316128}
#     Trial  264: host=hao-2           , ip=192.168.40.1   , value=0.0560292064   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010071945194753}
#     Trial  265: host=hao-2           , ip=192.168.40.1   , value=0.0560287757   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010041291903182181}
#     Trial  266: host=hao-2           , ip=192.168.40.1   , value=0.0560273946   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01009159375061011}
#     Trial  267: host=hao-2           , ip=192.168.40.1   , value=0.0560296612   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010015693027468998}
#     Trial  268: host=hao-2           , ip=192.168.40.1   , value=0.0560278030   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010646928409900518}
#     Trial  269: host=hao-2           , ip=192.168.40.1   , value=0.0562450846   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.25*mean', 'train_max_depth': 8, 'train_eta': 0.010731280403335713}
#     Trial  270: host=hao-2           , ip=192.168.40.1   , value=0.0560272003   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010653412729106517}
#     Trial  271: host=hao-2           , ip=192.168.40.1   , value=0.0560290546   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010744088109065556}
#     Trial  272: host=hao-2           , ip=192.168.40.1   , value=0.0616368274   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0.75*mean', 'train_max_depth': 8, 'train_eta': 0.010674413405842112}
#     Trial  273: host=hao-2           , ip=192.168.40.1   , value=0.0560288068   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010643598598790608}
#     Trial  274: host=hao-2           , ip=192.168.40.1   , value=0.0560806987   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 9, 'train_eta': 0.01127325532892944}
#     Trial  275: host=hao-2           , ip=192.168.40.1   , value=0.0560285631   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.010708006116971662}
#     Trial  276: host=hao-2           , ip=192.168.40.1   , value=0.0560292383   , params={'use_feature_gen': False, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01071548328845333}
#     Trial  277: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 10, 'selector_threshold': '0*mean', 'train_max_depth': 8, 'train_eta': 0.01127306233194053}
#     总 trial 数量: 278
# ====================================================================================================
# - Predicting Road Accident Risk LightGBM
#          Trials:
#     Trial    0: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': True, 'use_pca': False, 'pca_components': 15, 'learning_rate': 0.0055996820153367275, 'num_leaves': 195, 'min_data_in_leaf': 74, 'feature_fraction': 0.914800946534617, 'bagging_fraction': 0.9446609219617099, 'bagging_freq': 9, 'lambda_l1': 0.011866822156070662, 'lambda_l2': 0.3380745185379475, 'boosting_type': 'dart'}
#     Trial    1: host=unknown         , ip=unknown        , value=None           , params={'use_feature_gen': False, 'use_pca': True, 'pca_components': 5, 'learning_rate': 0.006562808119672416, 'num_leaves': 79, 'min_data_in_leaf': 28, 'feature_fraction': 0.9962004336453062, 'bagging_fraction': 0.6871421405909417, 'bagging_freq': 2, 'lambda_l1': 0.4311442275510067, 'lambda_l2': 0.0019544874210984733, 'boosting_type': 'dart'}
#     总 trial 数量: 2
# ====================================================================================================

# %%
# 清理前：先查看数据库里当前有哪些 study 存在，以及每个 study 里有多少个 trial

storage = "mysql+pymysql://user1:123456@10.162.147.95:3306/kaggle_melting_point_optuna"

studies = optuna.study.get_all_study_summaries(storage=storage)
print("现有 study：", [s.study_name for s in studies])

for s in studies:
    study = optuna.load_study(study_name=s.study_name, storage=storage)
    print(f"Study:   {s.study_name:30s}, Trials: {len(study.trials):4d}")
# Out:
# 现有 study： ['optuna_task1', 'test', 'test2', 'Predicting Road Accident Risk']
# Study:   optuna_task1                  , Trials:   33
# Study:   test                          , Trials:    4
# Study:   test2                         , Trials:   10
# Study:   Predicting Road Accident Risk , Trials:  278

# %%
# 清理中：删除指定 study
# 指定要删除的名称
to_delete = ["melting_point_study"]   # 可以写一个或多个

to_delete = [            ]

for s in studies:
    if s.study_name in to_delete:
        optuna.delete_study(study_name=s.study_name, storage=storage)
        print("已删除:", s.study_name)

# %%
# 清理后：再次检查
studies_after = optuna.study.get_all_study_summaries(storage=storage)
print("清理后 study：", [s.study_name for s in studies_after])
